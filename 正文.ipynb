# %% [markdown]
# # 正文: Optimal Phonetic Component Analysis

# %% [markdown]
# *(Tip: use **Run -> Run All Cells** to execute full analysis!)*

# %% [markdown]
# ## Stage 1. Load Unihan data

# %%
import pandas as pd
import json
import re
import csv
import unicodedata
from collections import Counter

import typing

## Output files: don't change these
RESULT_CSV = "result/Stats.csv"

## Based on the Unihan data file format specs (you probably don't need to change these)
DATAFILE_PATH = "data/Unihan_%s.txt"
DATAFILE_DELIM = '\t'
DATAFILE_COMMENT = '#'
DATAFILE_BASENAMES = ['codepoint', 'prop', 'val'] # The values will get renamed according to PROPS_NAMES
DATA_DIR = "data/%s"

# Unihan data files we need (and what properties they provide of interest to us)
SOURCES = {
    "DictionaryLikeData": ["kPhonetic"],
    "Readings": ["kMandarin"],
    "Variants": ["kSimplifiedVariant"],
}
# What to rename each of the properties desired above [OPTIONAL]
PROPS_NAMES = {
    "kMandarin": "read",
    "kPhonetic": "write",
    "kSimplifiedVariant": "simplified",
}

# Will get populated by loadData()
DATAFRAMES = {}

def loadData():
    global DATAFRAMES

    for source in SOURCES:
        sourceDF = pd.read_csv(DATAFILE_PATH % source, delimiter=DATAFILE_DELIM, comment=DATAFILE_COMMENT,
                               header=None, names=DATAFILE_BASENAMES)
        for prop in SOURCES[source]:
            print(f"[*]\t {prop} [{source}]")
            DATAFRAMES[prop] = sourceDF[sourceDF['prop'] == prop] \
                .drop('prop', axis=1) \
                .rename(columns={'val': PROPS_NAMES.get(prop, prop)}) \
                .reset_index(drop=True)

## Stage 1: Data loading
print("[*] Loading data:")

# DataFrame Reading
loadData()
pinyin_df = DATAFRAMES['kMandarin']
radical_df = DATAFRAMES['kPhonetic']

t2s_table = DATAFRAMES['kSimplifiedVariant']
def t2s_convert(codepoint: str):
    conversion = t2s_table[t2s_table['codepoint'] == codepoint]
    if not len(conversion):
        return codepoint
    return conversion.iloc[0]['simplified'].split(' ')[0] # If there are multiple possible conversions, return the first
    # (most likely) one

def strip(s):
    s = s.translate(str.maketrans("ǖǘǚǜ", "vvvv"))
    normalized = unicodedata.normalize('NFD', s)
    return ''.join(ch for ch in normalized if unicodedata.category(ch) != 'Mn')

# Format pinyin_df
pinyin_df["read"] = pinyin_df["read"].apply(strip)
pinyin_df["read"] = pinyin_df["read"].astype(str).str.replace("v", "ü")
# Duplicate readings
pinyin_df["read"] = pinyin_df["read"].astype(str).str.strip()
pinyin_df = (pinyin_df.assign(read=pinyin_df["read"].str.split(r"[\s,]+")).explode("read").reset_index(drop=True))

# Format radical_df
radical_df["write"] = radical_df["write"].astype(str).str.replace("*", "", regex=False)
radical_df["write"] = radical_df["write"].astype(str).apply(lambda s: [w for w in s.split() if 'x' not in w]) # each radical
# may belong to multiple phonetic groups (e.g. it contains one phonetic component which is a subcomponent of another in it).
# we want to keep these group IDs as lists, so we can group each character multiple times below.
radical_df = radical_df.reset_index(drop=True)

# Make the phonetic dictionary
radical_df['char'] = radical_df['codepoint'].apply(t2s_convert).apply(lambda x: chr(int(x[2:], 16)))
phonetic_dict = radical_df.explode('write').groupby('write')['char'].apply(list).to_dict()

print("[+] Data loaded!")
# Out:
# [*] Loading data:
# [*]	 kPhonetic [DictionaryLikeData]
# [*]	 kMandarin [Readings]
# [*]	 kSimplifiedVariant [Variants]
# [+] Data loaded!

# %% [markdown]
# #### Examine

# %%
radical_df
# Out:
#       codepoint         write char
# 0        U+3405   [954, 1156]    㐅
# 1        U+340C  [1471, 1545]    㐌
# 2        U+341F         [365]    㐟
# 3        U+3421        [1631]    㐡
# 4        U+3424          [63]    㐤
# ...         ...           ...  ...
# 22451   U+322E7        [1167]    𲋧
# 22452   U+322E8         [537]    𲋨
# 22453   U+322F9         [101]    𲋹
# 22454   U+32313       [1257A]    𲌓
# 22455   U+3232B         [926]    𲌫
#
# [22456 rows x 3 columns]

# %%
phonetic_dict
# Out:
# {'1': ['丫', '吖'],
#  '10': ['㡸',
#   '㸲',
#   '𮉣',
#   '䝫',
#   '䟭',
#   '䩆',
#   '乍',
#   '作',
#   '厏',
#   '咋',
#   '妰',
#   '岝',
#   '岞',
#   '怍',
#   '怎',
#   '拃',
#   '昨',
#   '柞',
#   '泎',
#   '炸',
#   '痄',
#   '砟',
#   '祚',
#   '秨',
#   '窄',
#   '笮',
#   '胙',
#   '舴',
#   '苲',
#   '蚱',
#   '诈',
#   '诈',
#   '迮',
#   '酢',
#   '𬬽',
#   '阼',
#   '𫗢',
#   '鲊',
#   '鲊',
#   '𱌬',
#   '𡗸',
#   '𢂃',
#   '𣬿',
#   '𥅁',
#   '𥹁',
#   '𦥬',
#   '𧯤',
#   '𧲮',
#   '𨋘',
#   '𩂖',
#   '𩢐',
#   '𩬟',
#   '𪌟'],
#  '100': ['只', '矍', '蒦', '只'],
#  '1000': ['旅', '派', '脉', '脉', '衇', '𠂢'],
#  '1001': ['牌', '簰'],
#  '1002': ['㓦',
#   '㢶',
#   '㪶',
#   '㹮',
#   '㼣',
#   '佰',
#   '咟',
#   '帞',
#   '弼',
#   '栢',
#   '洦',
#   '瓸',
#   '百',
#   '皕',
#   '粨',
#   '絔',
#   '袹',
#   '貊',
#   '銆',
#   '陌',
#   '𧻙',
#   '𩢷'],
#  '1002A': ['㴼', '宿', '樎', '𩘰'],
#  '1003': ['伯',
#   '帕',
#   '帛',
#   '廹',
#   '怕',
#   '拍',
#   '柏',
#   '泊',
#   '珀',
#   '白',
#   '百',
#   '皋',
#   '皐',
#   '穆',
#   '粕',
#   '胉',
#   '舶',
#   '迫',
#   '铂',
#   '魄',
#   '𦫖',
#   '𦫙'],
#  '1003A': ['碧'],
#  '1004': ['匐', '卜', '卜'],
#  '1005': ['斑', '班', '𢴬', '𤡰'],
#  '1005A': ['癍'],
#  '1006': ['扳', '攀', '袢', '襻'],
#  '1007': ['㱶',
#   '嘭',
#   '彭',
#   '憉',
#   '澎',
#   '甏',
#   '膨',
#   '蟚',
#   '蟛',
#   '𤡭',
#   '𥛱',
#   '𫄵',
#   '𨅘',
#   '𨎧'],
#  '1008': ['八', '匹', '叭', '扒', '掱', '趴'],
#  '1009': ['䀏', '勹', '勽', '匂', '包', '𠣑'],
#  '101': ['㤸',
#   '㫱',
#   '䓇',
#   '䚂',
#   '䞰',
#   '䤲',
#   '𬮨',
#   '䬉',
#   '哧',
#   '捇',
#   '浾',
#   '焃',
#   '硳',
#   '赤',
#   '赥',
#   '赦',
#   '赩',
#   '赫',
#   '郝',
#   '頳',
#   '𡋽',
#   '𡘥',
#   '𡨁',
#   '𣇐',
#   '𤙮',
#   '𥙼',
#   '𦀗',
#   '𦛘',
#   '𧨃',
#   '𧹛',
#   '𧹞',
#   '𧹤',
#   '𧹦',
#   '𧹪',
#   '𧹰',
#   '𨁯',
#   '𨲂',
#   '𨹮',
#   '𩭑',
#   '𩷧',
#   '𪁌',
#   '𪜻',
#   '𪠇',
#   '𪲒',
#   '𫐨',
#   '𫰭',
#   '𬏭',
#   '𬮨',
#   '𭮒',
#   '𭴩',
#   '𭹍',
#   '𮰊',
#   '𱺝',
#   '𲄠',
#   '𲊼',
#   '𲋹'],
#  '1010': ['勺', '杓', '豹', '趵'],
#  '1011': ['䶌',
#   '刨',
#   '包',
#   '匏',
#   '咆',
#   '孢',
#   '庖',
#   '抱',
#   '枹',
#   '泡',
#   '炮',
#   '炰',
#   '狍',
#   '瓟',
#   '疱',
#   '砲',
#   '胞',
#   '苞',
#   '袌',
#   '袍',
#   '跑',
#   '铇',
#   '雹',
#   '鞄',
#   '饱',
#   '鲍',
#   '麅',
#   '龅',
#   '𨠖',
#   '𪏶'],
#  '1012': ['闭', '𫼫', '𣘥'],
#  '1013': ['别',
#   '币',
#   '币',
#   '弊',
#   '别',
#   '憋',
#   '撆',
#   '撇',
#   '敝',
#   '毙',
#   '毙',
#   '獘',
#   '瞥',
#   '蔽',
#   '蹩',
#   '鄨',
#   '鳖',
#   '鳖',
#   '𫜁',
#   '𱌇',
#   '𡚁',
#   '𢠳',
#   '𫜁',
#   '𱌇'],
#  '1013A': ['㡀', '㢼', '䘷', '䭱', '𫛮', '𡘴', '𪐆', '𫛮'],
#  '1014': ['北', '背', '軰', '邶', '鉳'],
#  '1015': ['揼', '泵'],
#  '1016': ['斌', '赟', '赟', '𨭉'],
#  '1017': ['豳'],
#  '1018': ['㯽',
#   '傧',
#   '嫔',
#   '摈',
#   '梹',
#   '槟',
#   '殡',
#   '滨',
#   '濵',
#   '膑',
#   '宾',
#   '賔',
#   '鬓',
#   '𡣕',
#   '𣩵',
#   '𦆯',
#   '𧓍',
#   '𧸈',
#   '𨮘',
#   '𩪯',
#   '𩯭'],
#  '1019': ['喯', '奔', '捹', '犇', '逩', '锛', '𱃼'],
#  '102': ['呎', '尺', '局', '粎'],
#  '1020': ['㱵',
#   '𬏷',
#   '䒈',
#   '䩿',
#   '䴅',
#   '偾',
#   '偾',
#   '喷',
#   '喷',
#   '坟',
#   '坟',
#   '𪩸',
#   '愤',
#   '愤',
#   '𰗺',
#   '𬅫',
#   '𣸣',
#   '𰞻',
#   '𰡞',
#   '𫅗',
#   '𪱥',
#   '𰱟',
#   '豮',
#   '豮',
#   '贲',
#   '贲',
#   '𮝷',
#   '𫔁',
#   '𱀡',
#   '𱄀',
#   '𬳟',
#   '鲼',
#   '鲼',
#   '𱋱',
#   '𢊱',
#   '𢴢',
#   '𣯻',
#   '𣸣',
#   '𤖘',
#   '𬓱',
#   '𥳡',
#   '𧷐',
#   '𪩸',
#   '𪱥',
#   '𫅗',
#   '𫔁',
#   '𬅫',
#   '𬏷',
#   '𬓱',
#   '𬳟',
#   '𮝷',
#   '𰗺',
#   '𰞻',
#   '𰡞',
#   '𰱟',
#   '𱀡',
#   '𱄀',
#   '𱋱'],
#  '1020A': ['禀'],
#  '1021': ['临', '偘', '匲', '品', '板', '临', '板'],
#  '1022': ['㰋', '𫫾', '濒', '苹', '苹', '频', '颦'],
#  '1023': ['凭'],
#  '1024': ['㥊',
#   '䙀',
#   '䨜',
#   '倗',
#   '堋',
#   '奟',
#   '崩',
#   '弸',
#   '掤',
#   '朋',
#   '棚',
#   '淜',
#   '焩',
#   '痭',
#   '硼',
#   '稝',
#   '绷',
#   '绷',
#   '萠',
#   '𰺏',
#   '𬭖',
#   '鬅',
#   '鹏',
#   '鹏',
#   '𠜳',
#   '𠡮',
#   '𢉁',
#   '𢽩',
#   '𣂤',
#   '𣨥',
#   '𨂃',
#   '𨹹',
#   '𩋒',
#   '𬭖',
#   '𰺏'],
#  '1024A': ['䙖', '䣙', '傰', '剻', '嘣', '塴', '漰', '磞', '绷', '绷', '蹦', '镚', '镚'],
#  '1025': ['不',
#   '丕',
#   '否',
#   '咅',
#   '坏',
#   '孬',
#   '抔',
#   '杯',
#   '甭',
#   '盃',
#   '𰫽',
#   '罘',
#   '胚',
#   '芣',
#   '钚',
#   '阫'],
#  '1026': ['哔', '彃', '毕', '毕', '筚', '𰬎', '𬙝', '荜', '跸', '𫖒'],
#  '1027': ['发',
#   '坺',
#   '帗',
#   '拔',
#   '沷',
#   '犮',
#   '盋',
#   '祓',
#   '绂',
#   '胈',
#   '茇',
#   '跋',
#   '𫐈',
#   '钹',
#   '韨',
#   '髪',
#   '发',
#   '魃',
#   '黻',
#   '鼥',
#   '𦤚'],
#  '1027A': ['匹', '疋'],
#  '1028': ['㖣',
#   '㟝',
#   '㥉',
#   '㪗',
#   '㰴',
#   '㾦',
#   '䋨',
#   '䍌',
#   '䎧',
#   '䏽',
#   '䞳',
#   '𮸦',
#   '䫓',
#   '䬏',
#   '䯽',
#   '䳝',
#   '𱋝',
#   '倍',
#   '剖',
#   '勏',
#   '咅',
#   '培',
#   '婄',
#   '掊',
#   '敨',
#   '棓',
#   '殕',
#   '毰',
#   '涪',
#   '焙',
#   '琣',
#   '瓿',
#   '碚',
#   '稖',
#   '箁',
#   '菩',
#   '赔',
#   '赔',
#   '踣',
#   '部',
#   '郶',
#   '醅',
#   '锫',
#   '锫',
#   '陪',
#   '鞛',
#   '𱃾',
#   '𡯳',
#   '𡯷',
#   '𢒷',
#   '𢮏',
#   '𤬃',
#   '𦩜'],
#  '1029': ['㗗',
#   '㪏',
#   '㼰',
#   '㽡',
#   '䇑',
#   '䚜',
#   '䠋',
#   '𬨌',
#   '𱂮',
#   '䰦',
#   '䱝',
#   '𫜔',
#   '俾',
#   '卑',
#   '啤',
#   '埤',
#   '婢',
#   '崥',
#   '庳',
#   '捭',
#   '朇',
#   '椑',
#   '渒',
#   '焷',
#   '牌',
#   '猈',
#   '琕',
#   '痺',
#   '睥',
#   '碑',
#   '禆',
#   '稗',
#   '箄',
#   '粺',
#   '𰬤',
#   '聛',
#   '脾',
#   '萆',
#   '蜱',
#   '裨',
#   '諀',
#   '豍',
#   '貏',
#   '郫',
#   '𰾎',
#   '陴',
#   '鞞',
#   '髀',
#   '鹎',
#   '鹎',
#   '鼙',
#   '𪐄',
#   '𫜔',
#   '𬨌',
#   '𰬤',
#   '𰾎',
#   '𱂮'],
#  '1029A': ['蠯'],
#  '103': ['㐩',
#   '㘫',
#   '䎴',
#   '井',
#   '刑',
#   '刱',
#   '剏',
#   '剙',
#   '妌',
#   '开',
#   '形',
#   '汫',
#   '畊',
#   '穽',
#   '耕',
#   '肼',
#   '进',
#   '邢',
#   '阱',
#   '𧗦',
#   '𨥙'],
#  '1030': ['㿫',
#   '䃾',
#   '䘡',
#   '䩃',
#   '仳',
#   '吡',
#   '坒',
#   '妣',
#   '屁',
#   '庇',
#   '批',
#   '枇',
#   '枈',
#   '比',
#   '毕',
#   '毖',
#   '毗',
#   '毘',
#   '毞',
#   '沘',
#   '玭',
#   '琵',
#   '疪',
#   '砒',
#   '秕',
#   '笓',
#   '粃',
#   '粊',
#   '纰',
#   '纰',
#   '肶',
#   '舭',
#   '芘',
#   '蚍',
#   '豼',
#   '𬬫',
#   '阰',
#   '𢻹',
#   '𣢋',
#   '𣬆',
#   '𣬉',
#   '𣬋',
#   '𤘤',
#   '𤜻',
#   '𤽊',
#   '𤿎',
#   '𦊁',
#   '𧺲',
#   '𧿥',
#   '𨚍',
#   '𨟵',
#   '𩉫',
#   '𩨨',
#   '𪊕',
#   '𪌈'],
#  '1030A': ['梐', '狴', '陛'],
#  '1031': ['劓', '擤', '淠', '濞', '畀', '痹', '鼻', '𪖕'],
#  '1032': ['辔'],
#  '1033': ['匕', '庀', '比', '牝', '麀', '龀', '𠤏'],
#  '1034': ['䓒', '偹', '备', '备', '惫', '糒', '鞴', '𫖔', '𤰇'],
#  '1034A': ['惫'],
#  '1035': ['㚰',
#   '𫄞',
#   '䪹',
#   '𱉖',
#   '丕',
#   '伾',
#   '呸',
#   '噽',
#   '坯',
#   '岯',
#   '怌',
#   '抷',
#   '柸',
#   '狉',
#   '秠',
#   '苤',
#   '豾',
#   '邳',
#   '𰽧',
#   '𬳵',
#   '髬',
#   '𢓖',
#   '𤘹',
#   '𤵛',
#   '𥹂',
#   '𩎜'],
#  '1035A': ['胚'],
#  '1036': ['啚', '鄙'],
#  '1037': ['媲', '篦', '膍', '蓖', '貔', '𣬉', '𣬋'],
#  '1038': ['㓟',
#   '㝿',
#   '㢰',
#   '㱟',
#   '䏢',
#   '䝛',
#   '佊',
#   '坡',
#   '岥',
#   '帔',
#   '彼',
#   '怶',
#   '披',
#   '柀',
#   '波',
#   '狓',
#   '玻',
#   '疲',
#   '皮',
#   '破',
#   '秛',
#   '簸',
#   '紴',
#   '翍',
#   '耚',
#   '蚾',
#   '被',
#   '诐',
#   '诐',
#   '𬥶',
#   '跛',
#   '铍',
#   '铍',
#   '陂',
#   '鞁',
#   '颇',
#   '颇',
#   '𫘟',
#   '骳',
#   '髲',
#   '鲏',
#   '鲏',
#   '𡛡',
#   '𫘟',
#   '𬥶'],
#  '1039': ['䀌', '奭', '皕'],
#  '104': ['掷', '踯', '郑', '郑'],
#  '1040': ['僻',
#   '劈',
#   '噼',
#   '壁',
#   '嬖',
#   '幦',
#   '擗',
#   '擘',
#   '檗',
#   '澼',
#   '璧',
#   '甓',
#   '癖',
#   '臂',
#   '薜',
#   '襞',
#   '譬',
#   '躃',
#   '躄',
#   '辟',
#   '避',
#   '辟',
#   '霹',
#   '𤴣'],
#  '1041': ['笾', '边', '边'],
#  '1042': ['㓲',
#   '㞈',
#   '㲢',
#   '㴜',
#   '㻞',
#   '㼐',
#   '㾫',
#   '𰬁',
#   '䐔',
#   '䡢',
#   '䭏',
#   '偏',
#   '匾',
#   '媥',
#   '徧',
#   '惼',
#   '扁',
#   '揙',
#   '斒',
#   '楄',
#   '煸',
#   '牑',
#   '犏',
#   '猵',
#   '甂',
#   '碥',
#   '稨',
#   '篇',
#   '糄',
#   '编',
#   '编',
#   '翩',
#   '艑',
#   '萹',
#   '蝙',
#   '褊',
#   '谝',
#   '谝',
#   '蹁',
#   '遍',
#   '鍽',
#   '𱅝',
#   '骗',
#   '骗',
#   '鳊',
#   '鳊',
#   '𬸜',
#   '𠋅',
#   '𠪂',
#   '𠷨',
#   '𡎚',
#   '𡺂',
#   '𢉞',
#   '𢐃',
#   '𣩀',
#   '𤬊',
#   '𥚹',
#   '𦑮',
#   '𧡤',
#   '𨲜',
#   '𩩯',
#   '𩴄',
#   '𬸸',
#   '𪏗',
#   '𪖯',
#   '𫕌',
#   '𬸜',
#   '𬸸',
#   '𭨿',
#   '𭶳',
#   '𮸸',
#   '𰀙',
#   '𰬁',
#   '𱅝',
#   '𱖄',
#   '𱜯'],
#  '1042A': ['藊'],
#  '1043': ['砭', '窆', '贬'],
#  '1044': ['卞', '忭', '抃', '汴', '炞', '犿', '玣', '笇', '苄', '𱃴', '𠯴', '𨳲', '𩰍'],
#  '1045': ['办', '瓣', '辡', '办', '辨', '辫', '辩'],
#  '1046': ['䧽', '宷', '番', '釆', '釈', '𢍏', '𤕽', '𨤘', '𨤚', '𩗞'],
#  '1047': ['㛹', '便', '楩', '箯', '缏', '鞭', '𠷊', '𣸇', '𦳄', '𧱩', '𨂯', '𨩫', '𨸇'],
#  '1048': ['弁', '畚', '𡘞'],
#  '1049': ['㭓',
#   '㳎',
#   '㺹',
#   '䒪',
#   '䣲',
#   '䪻',
#   '䮁',
#   '匥',
#   '峅',
#   '弁',
#   '拚',
#   '笲',
#   '𫔰',
#   '𱉡',
#   '𡗹',
#   '𡛞',
#   '𥹇',
#   '𥿋',
#   '𨋒',
#   '𨚕'],
#  '105': ['嚼', '爝', '爵', '皭', '釂'],
#  '1050': ['片'],
#  '1051': ['冫', '冰', '冯'],
#  '1052': ['乒', '乓', '兵', '宾', '梹', '浜'],
#  '1053': ['㑂',
#   '㔷',
#   '䇤',
#   '𰬃',
#   '丙',
#   '怲',
#   '抦',
#   '昞',
#   '昺',
#   '柄',
#   '氞',
#   '炳',
#   '病',
#   '眪',
#   '苪',
#   '邴',
#   '𰽥',
#   '陃',
#   '鞆',
#   '𠒝',
#   '𠛥',
#   '𢨿',
#   '𩬝'],
#  '1054': ['㨀', '棅', '秉', '𥡝', '𥪕'],
#  '1055': ['㔙',
#   '㤣',
#   '㻂',
#   '䈂',
#   '䑫',
#   '䦕',
#   '𱋔',
#   '并',
#   '剏',
#   '剙',
#   '垪',
#   '姘',
#   '屏',
#   '屛',
#   '帡',
#   '帲',
#   '并',
#   '幷',
#   '庰',
#   '恲',
#   '拼',
#   '栟',
#   '洴',
#   '瓶',
#   '甁',
#   '皏',
#   '硑',
#   '𰬔',
#   '缾',
#   '聠',
#   '胼',
#   '腁',
#   '艵',
#   '荓',
#   '蛢',
#   '𬣲',
#   '賆',
#   '跰',
#   '𫐌',
#   '輧',
#   '迸',
#   '逬',
#   '郱',
#   '𰽼',
#   '𱂦',
#   '饼',
#   '饼',
#   '骈',
#   '騈',
#   '骈',
#   '骿',
#   '鮩',
#   '𫛨',
#   '𠛼',
#   '𢆟',
#   '𢏳',
#   '𫐌',
#   '𫛨',
#   '𰬔',
#   '𰽼',
#   '𱂦'],
#  '1055A': ['摒'],
#  '1056': ['并', '掽', '普', '湴', '碰', '竝'],
#  '1057': ['䀻',
#   '䛣',
#   '䳙',
#   '俜',
#   '娉',
#   '梬',
#   '涄',
#   '甹',
#   '聘',
#   '骋',
#   '骋',
#   '𠷓',
#   '𠸮',
#   '𢓳',
#   '𥪁',
#   '𥭢',
#   '𥺒',
#   '𦀔',
#   '𦰝',
#   '𧚗',
#   '𧮹',
#   '𩩍',
#   '𫪆',
#   '𬫙',
#   '𭮯',
#   '𮜷',
#   '𱐚',
#   '𱟼'],
#  '1058': ['㛁',
#   '㼞',
#   '䍈',
#   '䶄',
#   '伻',
#   '匉',
#   '呯',
#   '坪',
#   '岼',
#   '平',
#   '怦',
#   '抨',
#   '枰',
#   '泙',
#   '玶',
#   '砰',
#   '秤',
#   '胓',
#   '苹',
#   '评',
#   '评',
#   '𰹽',
#   '𰿬',
#   '𬳴',
#   '鲆',
#   '鲆',
#   '𤖳',
#   '𤘾',
#   '𦓬',
#   '𧲺',
#   '𨠟',
#   '𩑳'],
#  '1058A': ['萍'],
#  '1059': ['㧙',
#   '䀣',
#   '䏟',
#   '䟤',
#   '䩛',
#   '𱂅',
#   '𫠈',
#   '佖',
#   '咇',
#   '妼',
#   '宓',
#   '必',
#   '怭',
#   '柲',
#   '毖',
#   '泌',
#   '珌',
#   '瑟',
#   '祕',
#   '秘',
#   '苾',
#   '袐',
#   '𰴕',
#   '邲',
#   '铋',
#   '铋',
#   '𮤲',
#   '𫗣',
#   '馝',
#   '𱅈',
#   '𮭤',
#   '𠚊',
#   '𠛡',
#   '𠨘',
#   '𢁽',
#   '𢗈',
#   '𣁉',
#   '𣢠',
#   '𤵘',
#   '𤽣',
#   '𥁑',
#   '𦣥',
#   '𨒜',
#   '𨠔',
#   '𨤩',
#   '𨸼',
#   '𪏺'],
#  '1059A': ['谧'],
#  '106': ['㢩',
#   '㣿',
#   '䂆',
#   '䄪',
#   '䪨',
#   '䵠',
#   '䶂',
#   '仢',
#   '勺',
#   '圴',
#   '妁',
#   '尥',
#   '尦',
#   '彴',
#   '扚',
#   '旳',
#   '杓',
#   '汋',
#   '灼',
#   '犳',
#   '玓',
#   '瓝',
#   '的',
#   '礿',
#   '约',
#   '约',
#   '肑',
#   '芍',
#   '虳',
#   '訋',
#   '豹',
#   '趵',
#   '酌',
#   '钓',
#   '钓',
#   '靮',
#   '馰',
#   '𬶄',
#   '𠚭',
#   '𠮭',
#   '𡚷',
#   '𢁕',
#   '𢻭',
#   '𣧀',
#   '𤿈',
#   '𤿉',
#   '𥐝',
#   '𥩘',
#   '𥫩',
#   '𦉹',
#   '𦨓',
#   '𧘑',
#   '𧺕',
#   '𩖚',
#   '𩚈',
#   '𩲃',
#   '𩾡',
#   '𪪊',
#   '𪾠',
#   '𬏀',
#   '𬶄',
#   '𭘅',
#   '𰄛',
#   '𰅝',
#   '𰹋',
#   '𲆏'],
#  '1060': ['㿜', '瘪', '瘪'],
#  '1061': ['别', '别', '捌'],
#  '1062': ['㩠',
#   '𬴍',
#   '儦',
#   '瀌',
#   '爊',
#   '皫',
#   '穮',
#   '臕',
#   '藨',
#   '镳',
#   '镳',
#   '麃',
#   '𡂘',
#   '𡾌',
#   '𥶔',
#   '𦔩',
#   '𩙒'],
#  '1063': ['彪', '滮'],
#  '1063A': ['髟'],
#  '1064': ['猋', '𱃠', '飚', '𮸼'],
#  '1065': ['俵', '婊', '表', '裱', '表'],
#  '1066': ['僄',
#   '剽',
#   '嘌',
#   '嫖',
#   '彯',
#   '摽',
#   '标',
#   '标',
#   '漂',
#   '熛',
#   '瓢',
#   '瘭',
#   '瞟',
#   '磦',
#   '示',
#   '票',
#   '缥',
#   '膘',
#   '螵',
#   '镖',
#   '飃',
#   '飘',
#   '骠',
#   '鳔'],
#  '1066A': ['薸'],
#  '1067': ['鸨', '𠤏'],
#  '1068': ['㨐',
#   '㷛',
#   '䭋',
#   '䳰',
#   '保',
#   '堡',
#   '媬',
#   '椺',
#   '湺',
#   '煲',
#   '緥',
#   '葆',
#   '褒',
#   '褓',
#   '襃',
#   '賲',
#   '𩭼'],
#  '1069': ['㚴',
#   '㳍',
#   '佈',
#   '咘',
#   '布',
#   '怖',
#   '抪',
#   '柨',
#   '钸',
#   '钸',
#   '𢁻',
#   '𢇴',
#   '𣧦',
#   '𤙅',
#   '𥑢',
#   '𥞎',
#   '𧙛',
#   '𨋞',
#   '𩶉'],
#  '107': ['雀', '𪖀'],
#  '1070': ['廍', '篰', '蔀', '部', '𠘁', '𣘙', '𩅇'],
#  '1071': ['㻉',
#   '㾟',
#   '䑰',
#   '䤮',
#   '埗',
#   '徏',
#   '捗',
#   '步',
#   '荹',
#   '踄',
#   '陟',
#   '频',
#   '频',
#   '𡘧',
#   '𣦖',
#   '𤫻',
#   '𥹴',
#   '𨛒',
#   '𩊶',
#   '𩣝',
#   '𪌷'],
#  '1072': ['㩧',
#   '㿺',
#   '䂍',
#   '䤖',
#   '儤',
#   '嚗',
#   '懪',
#   '暴',
#   '曝',
#   '瀑',
#   '爆',
#   '襮',
#   '鑤',
#   '鸔',
#   '𦢊',
#   '𨇅',
#   '𩯱',
#   '𱊲'],
#  '1073': ['浦', '甫'],
#  '1073A': ['蒱', '蒲'],
#  '1073B': ['溥', '簿', '薄'],
#  '1073C': ['䥬', '礴'],
#  '1073D': ['匍', '葡'],
#  '1074': ['抱', '普', '氆', '谱', '镨'],
#  '1074A': ['菢'],
#  '1075': ['㨇', '啵', '婆', '波', '箥', '菠', '錃', '𠴸', '𥇲', '𩜥'],
#  '1076': ['勺', '叵', '尀', '笸', '钷'],
#  '1077': ['礟', '驳', '𱅐'],
#  '1078': ['泊', '箔', '萡'],
#  '1079': ['攴', '攵', '枚', '牧', '玫'],
#  '108': ['㦸', '倬', '卓', '婥', '悼', '掉', '桌', '棹', '淖', '焯', '绰', '繛', '罩', '踔'],
#  '1080': ['帮', '幚', '挷', '梆', '绑', '绑', '邦', '𠳐'],
#  '1081': ['㥬',
#   '㿶',
#   '䄘',
#   '䅭',
#   '䒍',
#   '䠙',
#   '䧛',
#   '䨦',
#   '䩷',
#   '傍',
#   '嗙',
#   '塝',
#   '嫎',
#   '嵭',
#   '徬',
#   '搒',
#   '旁',
#   '榜',
#   '滂',
#   '牓',
#   '磅',
#   '篣',
#   '𫄰',
#   '耪',
#   '膀',
#   '艕',
#   '蒡',
#   '螃',
#   '覫',
#   '谤',
#   '谤',
#   '镑',
#   '镑',
#   '𬴅',
#   '髈',
#   '鳑',
#   '鳑',
#   '𠗵',
#   '𢄎',
#   '𢐊',
#   '𣂆',
#   '𣯊',
#   '𣯟',
#   '𤚰',
#   '𤧭',
#   '𤹔',
#   '𥉣',
#   '𥻭',
#   '𦗍',
#   '𧤞',
#   '𨍩',
#   '𨜷',
#   '𨢐',
#   '𩡕',
#   '𪹚',
#   '𫄰',
#   '𫐼',
#   '𫜡',
#   '𬌿',
#   '𬳣',
#   '𬴅',
#   '𭥁',
#   '𮖧',
#   '𮤂',
#   '𰆊',
#   '𱂜',
#   '𱱼',
#   '𲁙'],
#  '1081A': ['尨', '霶'],
#  '1082': ['㔨', '偝', '揹', '背', '褙'],
#  '1083': ['呗',
#   '坝',
#   '宝',
#   '寳',
#   '宝',
#   '败',
#   '狈',
#   '贝',
#   '负',
#   '买',
#   '赑',
#   '贝',
#   '钡',
#   '𱉐'],
#  '1084': ['佩', '珮'],
#  '1085': ['沛', '霈'],
#  '1086': ['倍', '菩'],
#  '1087': ['搫', '搬', '槃', '瘢', '盘', '盘', '磐', '縏', '般', '鞶', '𨃞', '𨃟'],
#  '1088': ['体', '夲', '本', '砵', '笨', '钵', '苯', '躰', '钵'],
#  '1089': ['㪵',
#   '䉽',
#   '𱃷',
#   '伴',
#   '冸',
#   '判',
#   '半',
#   '叛',
#   '姅',
#   '怑',
#   '拌',
#   '柈',
#   '泮',
#   '牉',
#   '畔',
#   '秚',
#   '绊',
#   '绊',
#   '胖',
#   '衅',
#   '袢',
#   '跘',
#   '𰽰',
#   '靽',
#   '𬱙',
#   '𦚓',
#   '𧺾',
#   '𨒃',
#   '𩢔'],
#  '109': ['辶', '这', '逐', '这'],
#  '1090': ['潘', '籓', '藩'],
#  '1091': ['㖹', '湓', '盆', '葐', '𣱦', '𪂽'],
#  '1092': ['发', '癶', '癷', '癹', '发', '𦫔'],
#  '1093': ['勃', '孛', '悖', '浡', '𰬘', '脖', '荸', '誖', '饽', '鹁', '𦤣', '𩓐'],
#  '1093A': ['渤'],
#  '1094': ['仆', '卜', '圤', '扑', '朴', '盐', '补', '讣', '赴', '钋'],
#  '1095': ['仆',
#   '仆',
#   '墣',
#   '幞',
#   '扑',
#   '扑',
#   '暴',
#   '朴',
#   '朴',
#   '濮',
#   '璞',
#   '菐',
#   '襆',
#   '襥',
#   '蹼',
#   '𫐗',
#   '醭',
#   '镤'],
#  '1096': ['㸺', '娑', '挱', '挲', '沙', '痧', '莎', '莏', '蚋', '蚌', '裟', '鲨'],
#  '1097': ['世', '卅'],
#  '1098': ['耍'],
#  '1099': ['㿅',
#   '嘥',
#   '屣',
#   '徙',
#   '漇',
#   '簁',
#   '𫄳',
#   '蓰',
#   '褷',
#   '蹝',
#   '𢊚',
#   '𢒩',
#   '𣯪',
#   '𥛨'],
#  '11': ['义', '叉', '扠', '杈', '汊', '衩', '钗'],
#  '110': ['傽',
#   '嫜',
#   '嶂',
#   '幛',
#   '彰',
#   '慞',
#   '樟',
#   '漳',
#   '獐',
#   '璋',
#   '瘴',
#   '瞕',
#   '章',
#   '蔁',
#   '蟑',
#   '遧',
#   '鄣',
#   '鏱',
#   '障',
#   '騿',
#   '𫠒',
#   '麞',
#   '𢕔',
#   '𤍤',
#   '𩌬',
#   '𫜂'],
#  '1100': ['三', '仨', '兰', '卅', '叁', '弎', '闫'],
#  '1101': ['㐱',
#   '䀐',
#   '䑣',
#   '参',
#   '参',
#   '彡',
#   '杉',
#   '毝',
#   '衫',
#   '钐',
#   '钐',
#   '鬽',
#   '𠘱',
#   '𢁘',
#   '𢒆',
#   '𣲀',
#   '𧴭',
#   '𩁺'],
#  '1102': ['芟', '𣓒'],
#  '1103': ['亗',
#   '仙',
#   '山',
#   '岁',
#   '岔',
#   '岩',
#   '岚',
#   '嵒',
#   '氙',
#   '汕',
#   '灿',
#   '炭',
#   '疝',
#   '籼',
#   '籼',
#   '舢',
#   '讪',
#   '豳',
#   '𢌚'],
#  '1103A': ['𠕁'],
#  '1104': ['闩'],
#  '1105': ['㪚',
#   '䃟',
#   '䉈',
#   '撒',
#   '散',
#   '橵',
#   '潵',
#   '潸',
#   '澘',
#   '糤',
#   '𰬷',
#   '𫔌',
#   '霰',
#   '馓',
#   '馓',
#   '𠎭',
#   '𠪣',
#   '𠾎',
#   '𢄻',
#   '𢊰',
#   '𣽽',
#   '𤩀',
#   '𥂪',
#   '𥋌',
#   '𦠐',
#   '𦺻',
#   '𧝠',
#   '𧽾',
#   '𨅖',
#   '𪮫',
#   '𫔌',
#   '𮌼',
#   '𮣂',
#   '𰬷'],
#  '1106': ['伞', '伞'],
#  '1107': ['㻵', '僝', '孱', '樼', '潺', '𰺞', '骣', '骣', '𠟉', '𫔏'],
#  '1107A': ['生'],
#  '1108': ['㗂',
#   '㨘',
#   '㮐',
#   '㼳',
#   '㾪',
#   '䚇',
#   '偗',
#   '渻',
#   '省',
#   '箵',
#   '𡞞',
#   '𡨽',
#   '𢜫',
#   '𣦉',
#   '𦔄',
#   '𦳗',
#   '𨜜',
#   '𨲓',
#   '𨵥'],
#  '1109': ['䨿', '䪞', '𢶍'],
#  '111': ['张', '涨', '瘬', '𬦵'],
#  '1110': ['㬠', '煞', '繺', '𢅑'],
#  '1111': ['杀', '𬂮', '杀', '铩', '𬡕'],
#  '1112': ['㛉',
#   '䄽',
#   '䇴',
#   '哂',
#   '垔',
#   '廼',
#   '徆',
#   '恓',
#   '拪',
#   '晒',
#   '栖',
#   '毢',
#   '氥',
#   '洒',
#   '牺',
#   '硒',
#   '粞',
#   '𬘟',
#   '舾',
#   '茜',
#   '西',
#   '跴',
#   '迺',
#   '閪',
#   '𡧳',
#   '𡶼',
#   '𢬣',
#   '𤈇',
#   '𤞏',
#   '𤥒',
#   '𤶈',
#   '𤿢',
#   '𥙘',
#   '𦕩',
#   '𦚵',
#   '𧟪',
#   '𧧍',
#   '𨚹',
#   '𨠴',
#   '𪀹',
#   '𪎢',
#   '𫘊',
#   '𫙘',
#   '𬘟',
#   '𬠂',
#   '𬭄',
#   '𰕿',
#   '𱑝',
#   '𱝃',
#   '𱟷',
#   '𲇊',
#   '𲈹'],
#  '1112A': ['屖', '稺', '遟'],
#  '1113': ['墀', '樨', '犀', '稚', '穉', '迟', '迟'],
#  '1114': ['洗', '箲', '鍌'],
#  '1115': ['㰥',
#   '䄁',
#   '世',
#   '伳',
#   '卋',
#   '呭',
#   '屉',
#   '屉',
#   '怈',
#   '抴',
#   '朑',
#   '枻',
#   '枼',
#   '泄',
#   '玴',
#   '疶',
#   '笹',
#   '绁',
#   '绁',
#   '袣',
#   '𰵔',
#   '贳',
#   '贳',
#   '跇',
#   '迣',
#   '鉪',
#   '靾',
#   '髰',
#   '齛',
#   '𡛶',
#   '𢇸',
#   '𢺿',
#   '𤤙',
#   '𥅋',
#   '𥹑',
#   '𦐕',
#   '𦐞',
#   '𦭓',
#   '𧉺',
#   '𧺿',
#   '𩊈',
#   '𪣅',
#   '𬆑',
#   '𬔛',
#   '𬙚',
#   '𬡽',
#   '𮎉',
#   '𮓽',
#   '𰅲',
#   '𰵔',
#   '𱐬',
#   '𱐭',
#   '𱞉'],
#  '1115A': ['勚'],
#  '1116': ['噬', '澨', '筮', '遾', '𢶅', '𥰰'],
#  '1117': ['塞', '寨', '赛', '𡨄'],
#  '1118': ['㣺', '伈', '吢', '吣', '心', '忄', '忐', '忑', '沁', '芯'],
#  '1119': ['探', '深', '琛', '罙', '𫎩'],
#  '112': ['㢡',
#   '㯍',
#   '䉃',
#   '䊢',
#   '䒂',
#   '䵁',
#   '䵼',
#   '𰊈',
#   '奖',
#   '奨',
#   '奖',
#   '将',
#   '将',
#   '𡺃',
#   '𫽣',
#   '桨',
#   '桨',
#   '浆',
#   '浆',
#   '奖',
#   '蒋',
#   '蒋',
#   '螀',
#   '螀',
#   '𬧀',
#   '酱',
#   '酱',
#   '锵',
#   '锵',
#   '鳉',
#   '鳉',
#   '𠅵',
#   '𡺃',
#   '𣩗',
#   '𤍵',
#   '𤨿',
#   '𤴠',
#   '𧽩',
#   '𨄚',
#   '𨫥',
#   '𩝫',
#   '𩝴',
#   '𩱑',
#   '𪙝',
#   '𪤖',
#   '𫌏',
#   '𫦋',
#   '𫦋',
#   '𫳻',
#   '𫽣',
#   '𬦞',
#   '𬧀',
#   '𭊟',
#   '𭒝',
#   '𭲎',
#   '𮠿',
#   '𰊈',
#   '𰎲'],
#  '1120': ['森', '潹', '𠘆', '𠾤', '𢊲', '𣡕', '𤏗', '𩕌'],
#  '1121': ['婶', '审', '审', '沈', '谉'],
#  '1122': ['㖗', '䤫', '𬱣', '侺', '岑', '梣', '涔', '琌', '𢙿', '𮭦'],
#  '1123': ['勘',
#   '堪',
#   '尠',
#   '嵁',
#   '戡',
#   '揕',
#   '斟',
#   '椹',
#   '湛',
#   '煁',
#   '甚',
#   '碪',
#   '糂',
#   '葚',
#   '谌',
#   '踸',
#   '黮'],
#  '1124': ['亲', '宰', '峷', '梓', '莘', '辛', '辞', '辤', '辞', '锌', '骍', '𨐍'],
#  '1124A': ['新', '亲'],
#  '1124B': ['薪'],
#  '1125': ['身'],
#  '1126': ['伸',
#   '呻',
#   '坤',
#   '审',
#   '抻',
#   '氠',
#   '申',
#   '电',
#   '砷',
#   '神',
#   '绅',
#   '𬬹',
#   '陈',
#   '阵',
#   '陈',
#   '电'],
#  '1127': ['燊'],
#  '1128': ['刂', '嚚', '宦', '挋', '臣', '臤'],
#  '1129': ['㖘',
#   '㰮',
#   '㲀',
#   '䀼',
#   '䟴',
#   '䢅',
#   '䣅',
#   '䫃',
#   '侲',
#   '唇',
#   '娠',
#   '宸',
#   '屒',
#   '帪',
#   '振',
#   '敐',
#   '晨',
#   '桭',
#   '浱',
#   '祳',
#   '脣',
#   '脤',
#   '莀',
#   '蜃',
#   '裖',
#   '赈',
#   '赈',
#   '辰',
#   '辴',
#   '𫓵',
#   '陙',
#   '震',
#   '麎',
#   '𢛚',
#   '𢦿',
#   '𰬙',
#   '𨌑',
#   '𪁧',
#   '𪘝'],
#  '113': ['仉'],
#  '1130': ['𬸆',
#   '䴤',
#   '姓',
#   '徃',
#   '性',
#   '旌',
#   '星',
#   '栍',
#   '殅',
#   '泩',
#   '牲',
#   '狌',
#   '珄',
#   '生',
#   '甡',
#   '产',
#   '甥',
#   '甦',
#   '省',
#   '眚',
#   '笙',
#   '素',
#   '胜',
#   '苼',
#   '貹',
#   '𰽫',
#   '青',
#   '鼪',
#   '𠇷',
#   '𡉄',
#   '𣢡',
#   '𣬺',
#   '𤯡',
#   '𤯥'],
#  '1131': ['溼', '湿', '隰'],
#  '1132': ['什', '十', '卄', '卅', '卌', '叶', '氒', '汁', '率', '计', '针'],
#  '1133': ['濏', '瑟', '璱', '𫗋', '𦆄', '𨆙', '𩇣'],
#  '1134': ['虱', '蝨'],
#  '1135': ['㲳',
#   '𩧭',
#   '䰡',
#   '䳀',
#   '佚',
#   '劮',
#   '呹',
#   '失',
#   '妷',
#   '帙',
#   '怢',
#   '怣',
#   '抶',
#   '昳',
#   '柣',
#   '泆',
#   '瓞',
#   '眣',
#   '祑',
#   '秩',
#   '𮉢',
#   '翐',
#   '胅',
#   '苵',
#   '蛈',
#   '袟',
#   '袠',
#   '𰵙',
#   '趃',
#   '跌',
#   '轶',
#   '轶',
#   '迭',
#   '鉄',
#   '铁',
#   '镻',
#   '𱉚',
#   '𨳺',
#   '𨾤',
#   '𩧭',
#   '𩬭'],
#  '1136': ['寔', '实'],
#  '1137': ['滫', '脩', '蓨'],
#  '1138': ['収', '收', '荍', '𤙘'],
#  '1139': ['䡭', '羞', '馐', '𦟤', '𦪋', '𩘭'],
#  '114': ['掌', '撑'],
#  '1140': ['手', '找', '捚', '掱'],
#  '1141': ['䑹', '䤹', '䩳', '䬒', '䮟', '叜', '𠋢', '𠝬', '𠷃'],
#  '1142': ['㑏', '守', '狩', '酧', '𠱔', '𧵤'],
#  '1143': ['㟬',
#   '㥰',
#   '㪢',
#   '傁',
#   '叟',
#   '嗖',
#   '嫂',
#   '廋',
#   '搜',
#   '溲',
#   '獀',
#   '瘦',
#   '瞍',
#   '膄',
#   '艘',
#   '蓃',
#   '螋',
#   '𫍲',
#   '遚',
#   '鄋',
#   '醙',
#   '锼',
#   '锼',
#   '飕',
#   '飕',
#   '馊',
#   '𩨄',
#   '𠪇',
#   '𣯜',
#   '𤔣',
#   '𥰞',
#   '𧳶',
#   '𧽏',
#   '𩨄',
#   '𫍲'],
#  '1144': ['䭫',
#   '𬱯',
#   '䭮',
#   '渞',
#   '艏',
#   '衜',
#   '道',
#   '首',
#   '𠃺',
#   '𨲛',
#   '𩠑',
#   '𩠦',
#   '𩠯',
#   '𩠶',
#   '𩠹'],
#  '1145': ['䅎',
#   '䞬',
#   '唀',
#   '琇',
#   '秀',
#   '绣',
#   '绣',
#   '莠',
#   '诱',
#   '诱',
#   '透',
#   '锈',
#   '锈',
#   '頺',
#   '𢓵',
#   '𢭆',
#   '𥙾',
#   '𪁮'],
#  '1146': ['兽', '嘼', '兽'],
#  '1147': ['㵞', '僽', '愁', '矁', '𠿈'],
#  '1148': ['受', '授', '绶'],
#  '1149': ['㤽',
#   '𪫷',
#   '㹗',
#   '㿒',
#   '𤽯',
#   '𥺅',
#   '䌧',
#   '䓓',
#   '𩙧',
#   '䮻',
#   '𩾂',
#   '俦',
#   '俦',
#   '嚋',
#   '𭎜',
#   '寿',
#   '夀',
#   '𫝩',
#   '寿',
#   '𫝵',
#   '帱',
#   '帱',
#   '㤽',
#   '𢭏',
#   '梼',
#   '梼',
#   '涛',
#   '涛',
#   '焘',
#   '𬊍',
#   '焘',
#   '𰡽',
#   '畴',
#   '畴',
#   '祷',
#   '祷',
#   '筹',
#   '筹',
#   '𰭣',
#   '䓓',
#   '诪',
#   '诪',
#   '踌',
#   '踌',
#   '𮜶',
#   '醻',
#   '铸',
#   '铸',
#   '陦',
#   '陦',
#   '𱆛',
#   '𠠐',
#   '𢭏',
#   '𣀓',
#   '𫾳',
#   '𣋬',
#   '𣝷',
#   '𣤫',
#   '𣫐',
#   '𪺣',
#   '𤽯',
#   '𥌆',
#   '𪿞',
#   '𥺅',
#   '𦏟',
#   '𦡴',
#   '𦦰',
#   '𧈙',
#   '𫜷',
#   '𩕯',
#   '𩙧',
#   '𩟕',
#   '𩯦',
#   '𩾂',
#   '𬸍',
#   '𪫷',
#   '𪺣',
#   '𪿞',
#   '𮎍',
#   '𫋤',
#   '𫜷',
#   '𫝩',
#   '𫝵',
#   '𫾳',
#   '𬊍',
#   '𬢪',
#   '𬰯',
#   '𬸍',
#   '𭎜',
#   '𭷈',
#   '𮎍',
#   '𮖻',
#   '𮜶',
#   '𰡽',
#   '𰭣',
#   '𱆛'],
#  '115': ['像', '橡', '襐', '象', '𧰼'],
#  '1150': ['㝍', '写', '写', '泻', '泻'],
#  '1151': ['螫', '赦'],
#  '1152': ['倽', '啥', '舍', '猞', '舍'],
#  '1153': ['卸', '啣', '御', '𨓴', '𨨶'],
#  '1154': ['佘', '畲', '赊'],
#  '1155': ['㓔', '㴬', '射', '榭', '谢', '谢', '麝', '𤠭', '𧛼', '𩘧'],
#  '1155A': ['死'],
#  '1156': ['㐅', '卌', '呬', '四', '柶', '泗', '驷'],
#  '1156A': ['肆', '蕼'],
#  '1157': ['䇉',
#   '唘',
#   '妬',
#   '宕',
#   '拓',
#   '斫',
#   '柘',
#   '沰',
#   '石',
#   '砳',
#   '硕',
#   '磊',
#   '祏',
#   '跖',
#   '鼫',
#   '𥑟'],
#  '1158': ['䌃', '削', '揱', '箾', '萷', '鞩', '𠠄', '𣕇', '𣸛', '𦂗', '𦋞', '𨨺', '𪃅'],
#  '1159': ['商', '滳', '熵', '蔏', '𠼬', '𥊔', '𱊥'],
#  '116': ['㽴', '丈', '仗', '扙', '杖', '粀'],
#  '1160': ['上',
#   '儴',
#   '勷',
#   '嚷',
#   '囊',
#   '埌',
#   '壤',
#   '孃',
#   '攘',
#   '曩',
#   '瀼',
#   '獽',
#   '瓤',
#   '禳',
#   '穰',
#   '𬙋',
#   '蘘',
#   '襄',
#   '让',
#   '让',
#   '酿',
#   '酿',
#   '镶',
#   '镶',
#   '𫗵',
#   '骧',
#   '骧',
#   '𫗵',
#   '𬙋'],
#  '1161': ['䌮', '孀', '灀', '礵', '霜', '骦', '骦', '鹴', '鹴'],
#  '1162': ['㧐', '𫁷', '䝄', '双', '𪥫', '𮲮', '𰰋', '双', '𡾼', '𧄐', '𰸇', '𩆿'],
#  '1163': ['伤', '塲', '殇', '膓', '觞'],
#  '1164': ['偿', '偿', '赏'],
#  '1165': ['厢', '厢', '想', '湘', '相', '箱', '缃', '缃', '葙', '霜', '𤷼', '𧡮', '𪂼'],
#  '1166': ['㫖', '上', '仧', '仩', '尗', '让', '𠀝', '𠦋', '𠧕', '𠧛', '𠮳', '𠮵'],
#  '1167': ['㫾',
#   '㭻',
#   '㲂',
#   '䊑',
#   '䟫',
#   '䠀',
#   '䣊',
#   '倘',
#   '党',
#   '尝',
#   '埫',
#   '堂',
#   '尙',
#   '尚',
#   '尝',
#   '常',
#   '当',
#   '徜',
#   '惝',
#   '掌',
#   '敞',
#   '棠',
#   '淌',
#   '牚',
#   '甞',
#   '当',
#   '绱',
#   '绱',
#   '耥',
#   '裳',
#   '赏',
#   '赏',
#   '趟',
#   '躺',
#   '鋿',
#   '绱',
#   '党',
#   '𠶤',
#   '𡞀',
#   '𢉒',
#   '𢮐',
#   '𢻒',
#   '𣎃',
#   '𣮜',
#   '𤙽',
#   '𤷛',
#   '𤿼',
#   '𥓡',
#   '𦫢',
#   '𦰱',
#   '𧩡',
#   '𨌩',
#   '𨜂',
#   '𨿰',
#   '𩗵',
#   '𩜋',
#   '𪁺',
#   '𪽄',
#   '𫙥',
#   '𫨋',
#   '𫻹',
#   '𬓮',
#   '𬕒',
#   '𬡾',
#   '𬴬',
#   '𭝒',
#   '𭯝',
#   '𮞢',
#   '𮨏',
#   '𰕋',
#   '𱑸',
#   '𱿫',
#   '𲈆',
#   '𲋧'],
#  '1167A': ['𰈇', '鲿'],
#  '1167B': ['嫦'],
#  '1168': ['施', '椸', '𫄟', '葹'],
#  '1169': ['㟃',
#   '䏤',
#   '伺',
#   '司',
#   '呞',
#   '嗣',
#   '孠',
#   '柌',
#   '泀',
#   '祠',
#   '笥',
#   '𬢊',
#   '词',
#   '词',
#   '鉰',
#   '饲',
#   '𥄶',
#   '𥿆',
#   '𦭡',
#   '𧙈'],
#  '117': ['匠', '𪀘'],
#  '1170': ['丝', '奚', '糸', '系', '索', '细', '丝', '継', '继', '细', '继', '𢇁', '𮈔'],
#  '1170A': ['兹', '玆', '兹', '鸶', '鸶', '𠧦'],
#  '1170B': ['䏈',
#   '咝',
#   '咝',
#   '蕬',
#   '鸶',
#   '鸶',
#   '𣊡',
#   '𤡨',
#   '𦂞',
#   '𦃟',
#   '𦆩',
#   '𧑿',
#   '𨖾',
#   '𨭔',
#   '𨶹',
#   '𩕛',
#   '𪆓',
#   '𪦤',
#   '𪦥',
#   '𪷜',
#   '𫯼',
#   '𰙹'],
#  '1171': ['帅', '师', '浉', '狮', '瑡', '筛', '𰰳', '蛳', '鶳', '𤹌', '𬡔', '𩥐'],
#  '1172': ['俬', '私', '𦮺'],
#  '1173': ['㯕',
#   '㽄',
#   '䔮',
#   '䡳',
#   '凘',
#   '厮',
#   '嘶',
#   '厮',
#   '撕',
#   '斯',
#   '澌',
#   '燍',
#   '簛',
#   '𰾴',
#   '𡡒',
#   '𢠹',
#   '𣚄',
#   '𣤘',
#   '𣩠',
#   '𤺊',
#   '𥐀',
#   '𥕶',
#   '𧝤',
#   '𩅰',
#   '𪆁',
#   '𪆗',
#   '𪖉'],
#  '1174': ['㥸',
#   '㩄',
#   '㴓',
#   '䚡',
#   '䰄',
#   '偲',
#   '媤',
#   '崽',
#   '思',
#   '愢',
#   '揌',
#   '楒',
#   '毸',
#   '禗',
#   '缌',
#   '缌',
#   '罳',
#   '腮',
#   '葸',
#   '𫍰',
#   '锶',
#   '锶',
#   '𱂲',
#   '飔',
#   '飔',
#   '騦',
#   '鳃',
#   '鳃',
#   '𠅤',
#   '𠖓',
#   '𢛥',
#   '𤟧',
#   '𥯨',
#   '𦩭',
#   '𨜐',
#   '𪃄',
#   '𪕳',
#   '𫍰'],
#  '1175': ['嗁', '搋', '篪', '虒', '褫', '蹏', '递', '递'],
#  '1176': ['尉', '尸', '尸', '屎', '屑', '屃', '履', '屭', '犰', '鸤', '𡱆'],
#  '1177': ['㕜', '使', '史', '吏', '驶'],
#  '1178': ['埘', '旵', '时', '莳', '鲥'],
#  '1179': ['巿', '市', '柿', '肺', '铈'],
#  '118': ['卥', '囱', '囱', '悤', '窗', '𠧧'],
#  '1180': ['佘', '标', '沶', '示', '社', '祁', '祭', '视', '际'],
#  '1181': ['仕', '士', '壿', '志', '毐', '𡔛', '𡔜', '𡔣', '𡕁'],
#  '1181A': ['茌'],
#  '1182': ['亊', '事', '剚'],
#  '1183': ['偍',
#   '匙',
#   '堤',
#   '媞',
#   '寔',
#   '尟',
#   '提',
#   '是',
#   '昰',
#   '湜',
#   '禔',
#   '缇',
#   '翨',
#   '𬤊',
#   '踶',
#   '醍',
#   '隄',
#   '鞮',
#   '题',
#   '𫘨',
#   '鳀',
#   '𤟥'],
#  '1184': ['㞴',
#   '㡳',
#   '㹝',
#   '䉻',
#   '䟗',
#   '䲬',
#   '只',
#   '坁',
#   '帋',
#   '忯',
#   '扺',
#   '氏',
#   '氐',
#   '汦',
#   '疧',
#   '眂',
#   '祇',
#   '秖',
#   '纸',
#   '纸',
#   '舐',
#   '芪',
#   '只',
#   '觗',
#   '赿',
#   '𬨂',
#   '𠛊',
#   '𠨿',
#   '𡚼',
#   '𣏚',
#   '𣢎',
#   '𤯄',
#   '𥄇',
#   '𥫽',
#   '𦙆',
#   '𨟾',
#   '𨱡',
#   '𨸝',
#   '𨾛',
#   '𩉬'],
#  '1185': ['歰', '涩', '涩', '澁', '𰶎'],
#  '1186': ['㗭', '㣰', '㴽', '䊝', '僁', '悉', '窸', '蟋', '鏭'],
#  '1187': ['媳', '息', '憩', '熄', '螅', '鎴'],
#  '1188': ['䵥', '栬', '绝', '绝', '脃', '色', '铯', '铯', '𤶋', '𨹔'],
#  '1189': ['擿', '藡', '讁', '适', '适'],
#  '119': ['㫀',
#   '䅛',
#   '䗉',
#   '䞎',
#   '䮖',
#   '倡',
#   '唱',
#   '娼',
#   '昌',
#   '晿',
#   '椙',
#   '淐',
#   '焻',
#   '猖',
#   '琩',
#   '菖',
#   '裮',
#   '誯',
#   '锠',
#   '锠',
#   '阊',
#   '阊',
#   '鲳',
#   '鲳',
#   '䞎',
#   '𪂇',
#   '𬸶',
#   '𬸶'],
#  '1190': ['奭', '襫'],
#  '1191': ['啬', '啬', '𬈧', '穑', '蔷', '𰺙'],
#  '1192': ['㱤',
#   '䨛',
#   '唽',
#   '惁',
#   '晰',
#   '晳',
#   '析',
#   '椞',
#   '淅',
#   '皙',
#   '菥',
#   '蜤',
#   '蜥',
#   '𣨗',
#   '𥮥',
#   '𥺚',
#   '𩗱'],
#  '1193': ['侙',
#   '式',
#   '弑',
#   '弑',
#   '恜',
#   '拭',
#   '栻',
#   '烒',
#   '试',
#   '试',
#   '轼',
#   '轼',
#   '𫟸',
#   '𢂑',
#   '𢎎',
#   '𥅞',
#   '𥿮',
#   '𧵻',
#   '𩗎',
#   '𪉅',
#   '𪉅'],
#  '1194': ['㛭',
#   '㟙',
#   '㳻',
#   '䄍',
#   '䇎',
#   '䜺',
#   '䧿',
#   '借',
#   '剒',
#   '厝',
#   '唶',
#   '庴',
#   '徣',
#   '惜',
#   '措',
#   '斮',
#   '昔',
#   '棤',
#   '焟',
#   '猎',
#   '瘄',
#   '皵',
#   '矠',
#   '碏',
#   '耤',
#   '腊',
#   '蜡',
#   '趞',
#   '踖',
#   '逪',
#   '醋',
#   '错',
#   '错',
#   '鹊',
#   '鹊',
#   '𫜬',
#   '𦁎',
#   '𧹨',
#   '𨛳',
#   '𩊿',
#   '𩤈',
#   '𩭡',
#   '𪏈'],
#  '1195': ['写', '冩', '写', '潟', '舃', '舄'],
#  '1196': ['蚀', '食', '𬲦'],
#  '1197': ['陕', '陕', '鿃'],
#  '1198': ['𰓔', '𰛛', '䠾', '𤇄', '闪'],
#  '1199': ['侁',
#   '先',
#   '冼',
#   '姺',
#   '宪',
#   '朁',
#   '毨',
#   '洗',
#   '筅',
#   '诜',
#   '赞',
#   '跣',
#   '选',
#   '酰',
#   '铣',
#   '𬳽'],
#  '12': ['㞉',
#   '㷢',
#   '㿷',
#   '䁟',
#   '䐤',
#   '䑘',
#   '䡨',
#   '䰈',
#   '䴾',
#   '傞',
#   '嗟',
#   '嵯',
#   '嵳',
#   '差',
#   '搓',
#   '槎',
#   '溠',
#   '瑳',
#   '瘥',
#   '磋',
#   '𬘷',
#   '艖',
#   '蒫',
#   '褨',
#   '蹉',
#   '醝',
#   '𫟿',
#   '髊',
#   '鹾',
#   '𬺎',
#   '𣍏',
#   '𣩈'],
#  '120': ['鬯', '𥠴'],
#  '1200': ['𰝟', '䉳', '廯', '癣', '藓', '鲜', '𡾮', '𢥌', '𣟲', '𫏨', '𩆵'],
#  '1200A': ['尟', '尠'],
#  '1201': ['倩', '篟', '蒨', '𣹥'],
#  '1202': ['䡪', '䦂', '䦂', '傓', '扇', '搧', '煽', '骟', '骟', '𥔱', '𥰢', '𦶋'],
#  '1203': ['㪨',
#   '䦅',
#   '僐',
#   '善',
#   '墡',
#   '嫸',
#   '敾',
#   '橏',
#   '歚',
#   '磰',
#   '缮',
#   '缮',
#   '膳',
#   '蟮',
#   '鄯',
#   '䦅',
#   '饍',
#   '鳝',
#   '鳝',
#   '𢵈',
#   '𣩧',
#   '𤺪',
#   '𨣁',
#   '𬱱',
#   '𩦐',
#   '𬹎'],
#  '1204': ['檨', '羡', '羨'],
#  '1205': ['升', '昇', '竔', '陞'],
#  '1205A': ['声'],
#  '1206': ['䃏',
#   '惺',
#   '戥',
#   '星',
#   '湦',
#   '煋',
#   '猩',
#   '瑆',
#   '睲',
#   '篂',
#   '腥',
#   '醒',
#   '𰾝',
#   '𣌜',
#   '𣨾',
#   '𥠀',
#   '𦩠',
#   '𧛟',
#   '𧡶'],
#  '1207': ['圣', '柽', '圣', '蛏'],
#  '1208': ['胜',
#   '堘',
#   '塍',
#   '媵',
#   '朕',
#   '滕',
#   '畻',
#   '縢',
#   '胜',
#   '螣',
#   '誊',
#   '誊',
#   '𬂉',
#   '腾'],
#  '1209': ['关', '咲', '朕', '栚', '灷', '送', '𠔉'],
#  '121': ['丬',
#   '壮',
#   '壮',
#   '妆',
#   '将',
#   '床',
#   '戕',
#   '斨',
#   '爿',
#   '牀',
#   '牂',
#   '墙',
#   '状',
#   '臧',
#   '𢍿'],
#  '1210': ['丞', '巹', '承', '拯', '氶', '烝', '脀', '𨚡'],
#  '1210A': ['蒸'],
#  '1211': ['乘', '剩', '嵊', '溗', '𱅢', '𢟊'],
#  '1211A': ['绳'],
#  '1212': ['城', '宬', '成', '晟', '盛', '蒇', '诚', '郕'],
#  '1213': ['涉'],
#  '1213A': ['摄'],
#  '1214': ['窃', '窃'],
#  '1215': ['孼', '孽', '糵', '薛', '蘖', '躠', '辥', '𧕏'],
#  '1216': ['㣯',
#   '㨝',
#   '㴮',
#   '屑',
#   '榍',
#   '碿',
#   '糏',
#   '𡟩',
#   '𢞜',
#   '𤸮',
#   '𦞚',
#   '𦵱',
#   '𧜔',
#   '𪍛',
#   '𪙌'],
#  '1217': ['燮', '爕', '躞'],
#  '1218': ['咶', '敌', '舌', '适', '䞌'],
#  '1219': ['䔥', '潇', '潇', '萧', '蟏', '蟏'],
#  '122': ['墙', '嫱', '𪪞', '樯', '墙', '艢', '蔷', '蘠'],
#  '1220': ['吵',
#   '妙',
#   '小',
#   '少',
#   '尘',
#   '抄',
#   '沙',
#   '炒',
#   '玅',
#   '発',
#   '眇',
#   '砂',
#   '秒',
#   '纱',
#   '耖',
#   '肖',
#   '钞',
#   '𭕆'],
#  '1221': ['䄻',
#   '䠷',
#   '佻',
#   '兆',
#   '咷',
#   '垗',
#   '姚',
#   '恌',
#   '挑',
#   '旐',
#   '晁',
#   '桃',
#   '洮',
#   '珧',
#   '眺',
#   '祧',
#   '窕',
#   '筄',
#   '脁',
#   '𬢋',
#   '𫍥',
#   '跳',
#   '迯',
#   '逃',
#   '铫',
#   '鞉',
#   '𫖯',
#   '𱅏',
#   '鼗'],
#  '1222': ['肇'],
#  '1223': ['稣', '苏', '苏'],
#  '1223A': ['苏'],
#  '1223B': ['骚'],
#  '1224': ['㨞',
#   '䋤',
#   '䘘',
#   '傃',
#   '嗉',
#   '嫊',
#   '愫',
#   '榡',
#   '溸',
#   '素',
#   '縤',
#   '膆',
#   '𤠚',
#   '𥱨',
#   '𩔥'],
#  '1225': ['擞', '数', '数', '䉤', '薮'],
#  '1225A': ['臊'],
#  '1226': ['㽰', '旋', '楚', '疋', '疎', '疏', '胥', '𤴔'],
#  '1226A': ['蔬'],
#  '1227': ['唢', '琐', '锁', '鎻', '𭕆', '𧴲'],
#  '1228': ['傻', '儍'],
#  '1229': ['嗦', '溹', '索', '𫔅', '𢱢'],
#  '123': ['伥',
#   '帐',
#   '张',
#   '怅',
#   '𰓄',
#   '枨',
#   '𪽪',
#   '肆',
#   '胀',
#   '苌',
#   '账',
#   '长',
#   '镸',
#   '长',
#   '𮧴',
#   '𫗠',
#   '𱌊',
#   '𨲗'],
#  '1230': ['嗽',
#   '嫰',
#   '摗',
#   '樕',
#   '欶',
#   '漱',
#   '瘶',
#   '簌',
#   '蔌',
#   '遬',
#   '𨱒',
#   '𠘂',
#   '𤡃',
#   '𦌊',
#   '𨱒',
#   '𩮶'],
#  '1231': ['㮶', '嗍', '塑', '愬', '搠', '朔', '槊', '溯', '蒴', '遡', '𫔈', '𦃗'],
#  '1232': ['嗓', '搡', '桑', '磉', '颡', '𣞙'],
#  '1233': ['㼽',
#   '䫪',
#   '傸',
#   '塽',
#   '慡',
#   '摤',
#   '樉',
#   '漺',
#   '爽',
#   '磢',
#   '鏯',
#   '𫘭',
#   '𮭪',
#   '𠓷',
#   '𠗾',
#   '𠞮',
#   '𡻯',
#   '𥡠',
#   '𥱶',
#   '𬘾',
#   '𧴅'],
#  '1234': ['䘮', '丧', '丧'],
#  '1235': ['书', '圕', '昼', '书', '𤾭'],
#  '1236': ['䵓', '潻', '黍', '𪏦'],
#  '1237': ['癙', '窜', '窜', '鼠'],
#  '1238': ['嗻', '嫬', '庶', '摭', '蔗', '蟅', '蹠', '遮', '鹧'],
#  '1239': ['処', '处', '处', '𩂂'],
#  '124': ['巛', '灾', '𡿧'],
#  '1240': ['投', '杸', '殳', '祋', '羖', '股', '芟', '𨐅', '骰', '𡧔', '𦤂', '𨐅'],
#  '1240A': ['署'],
#  '1241': ['㛸', '㰻', '䐍', '壴', '壾', '尌', '鼓', '鼔', '𠊪', '𠷸', '𢜳', '𨔦'],
#  '1241A': ['厨', '树', '树', '澍'],
#  '1241B': ['厨'],
#  '1241C': ['亘', '竖', '竖'],
#  '1242': ['孙', '孙', '𰓧', '狲', '荪', '逊'],
#  '1243': ['飧', '飱'],
#  '1244': ['䳦',
#   '喧',
#   '媗',
#   '宣',
#   '愃',
#   '揎',
#   '暄',
#   '楦',
#   '渲',
#   '煊',
#   '瑄',
#   '睻',
#   '碹',
#   '箮',
#   '縇',
#   '萱',
#   '𬤎',
#   '鍹',
#   '𠝳',
#   '𡺟',
#   '𤟿',
#   '𧡢',
#   '𩋢',
#   '𩏆',
#   '𩘒',
#   '𩤡'],
#  '1244A': ['选', '𤂿', '𥶷'],
#  '1245': ['祘', '蒜'],
#  '1246': ['匴', '筭', '算', '篡', '篹', '簒', '籑', '纂'],
#  '1247': ['㯀',
#   '䁢',
#   '䃠',
#   '嫙',
#   '旋',
#   '漩',
#   '琁',
#   '璇',
#   '𰬵',
#   '蔙',
#   '旋',
#   '𢳄',
#   '𥪱',
#   '𧜽',
#   '𪍧'],
#  '1248': ['樰', '膤', '艝', '轌', '雪', '鳕', '鳕', '𠞯'],
#  '1249': ['㲤', '䙑', '榱', '滖', '簑', '缞', '缞', '蓑', '衰'],
#  '125': ['椔', '淄', '甾', '缁', '菑', '葘', '辎', '輺', '鲻'],
#  '1250': ['㹘',
#   '㽭',
#   '䇕',
#   '䞕',
#   '䨲',
#   '䰑',
#   '䰰',
#   '儒',
#   '嚅',
#   '壖',
#   '嬬',
#   '孺',
#   '嶿',
#   '懦',
#   '擩',
#   '曘',
#   '檽',
#   '濡',
#   '燸',
#   '獳',
#   '瓀',
#   '礝',
#   '穤',
#   '糯',
#   '𦈡',
#   '羺',
#   '臑',
#   '薷',
#   '蠕',
#   '襦',
#   '𰶌',
#   '轜',
#   '醹',
#   '𰿂',
#   '隭',
#   '需',
#   '颥',
#   '颥',
#   '𱈗',
#   '𠟺',
#   '𢐰',
#   '𣽉',
#   '𤻪',
#   '𥀫',
#   '𥀭',
#   '𥌎',
#   '𥎘',
#   '𥐎',
#   '𥜗',
#   '𦈡',
#   '𨷘',
#   '𩆟',
#   '𩍥',
#   '𩪰',
#   '𩴶',
#   '𪋯',
#   '𪎱',
#   '𫏧',
#   '𫗜',
#   '𭮥',
#   '𰶌',
#   '𰿂',
#   '𱈗'],
#  '1251': ['壻', '婿', '湑', '稰', '糈', '胥', '醑'],
#  '1252': ['媭', '湏', '须', '须', '须'],
#  '1253': ['水', '汆', '淼', '湏', '盥', '颒'],
#  '1254': ['刿', '哕', '嵗', '岁', '𰛦', '秽', '翙', '𱂤', '𢒱'],
#  '1255': ['倕',
#   '厜',
#   '唾',
#   '垂',
#   '埵',
#   '捶',
#   '棰',
#   '甀',
#   '睡',
#   '硾',
#   '箠',
#   '菙',
#   '𰵶',
#   '邮',
#   '邮',
#   '锤',
#   '陲',
#   '𡍮'],
#  '1256': ['㵖', '絮', '蕠'],
#  '1257': ['㒸', '遂', '队', '队'],
#  '1257A': ['㸂',
#   '䍁',
#   '𫟦',
#   '嬘',
#   '旞',
#   '檖',
#   '澻',
#   '燧',
#   '璲',
#   '礈',
#   '禭',
#   '穟',
#   '䍁',
#   '襚',
#   '譢',
#   '邃',
#   '𬭼',
#   '隧',
#   '鿪',
#   '𡀟',
#   '𡑞',
#   '𢅕',
#   '𢢝',
#   '𢷊',
#   '𣄚',
#   '𤻄',
#   '𥴦',
#   '𦼯',
#   '𧁂',
#   '𧸙',
#   '𨆏',
#   '𨣢',
#   '𨷃',
#   '𩍚',
#   '𫟦',
#   '𬭼',
#   '𭛉',
#   '𭿨',
#   '𮄜',
#   '𮕆',
#   '𰖱',
#   '𲂖',
#   '𲌓'],
#  '1258': ['咉', '粟'],
#  '1259': ['俶', '叔', '寂', '惄', '戚', '椒', '淑', '督', '菽', '裻', '𰵴', '踧'],
#  '126': ['㞢', '旹', '蚩'],
#  '1260': ['㝛', '宿', '缩', '蓿', '蹜', '𤛝'],
#  '1261': ['㴋',
#   '啸',
#   '啸',
#   '𰗹',
#   '𰙑',
#   '㴋',
#   '箫',
#   '箫',
#   '粛',
#   '绣',
#   '绣',
#   '绣',
#   '肃',
#   '肃',
#   '萧',
#   '萧',
#   '蟰',
#   '锈',
#   '锈',
#   '锈',
#   '骕',
#   '骕',
#   '𱇿',
#   '鹔',
#   '鹔',
#   '𰗹',
#   '𰙑',
#   '𰬩',
#   '𱇿'],
#  '1262': ['㑉', '㓘', '夙', '洬', '珟', '𤥔'],
#  '1263': ['䃞', '塾', '孰', '熟', '𨶝'],
#  '1264': ['㒔',
#   '㯮',
#   '㻿',
#   '䟉',
#   '䪅',
#   '䫳',
#   '䮷',
#   '劅',
#   '噣',
#   '擉',
#   '斀',
#   '斣',
#   '斶',
#   '歜',
#   '浊',
#   '浊',
#   '烛',
#   '烛',
#   '独',
#   '独',
#   '臅',
#   '薥',
#   '虫',
#   '蜀',
#   '蠋',
#   '蠲',
#   '襡',
#   '触',
#   '触',
#   '躅',
#   '镯',
#   '镯',
#   '𱂋',
#   '髑',
#   '𱊬',
#   '𢢗',
#   '𢻧',
#   '𣀈',
#   '𣂌',
#   '𤛯',
#   '𤢜',
#   '𥋛',
#   '𥖠',
#   '𥣋',
#   '𦆂',
#   '𦏕',
#   '𨊒',
#   '𨞕',
#   '𩁍',
#   '𩑂',
#   '𩞾',
#   '𩼟',
#   '𪇆',
#   '𪍹',
#   '𪦨',
#   '𭤦',
#   '𭷍',
#   '𮥦',
#   '𱂋',
#   '𱊬',
#   '𲆼'],
#  '1265': ['𨅛', '㔉', '嘱', '属', '属', '𣃁', '𣚚', '𪹳', '瞩', '𰾽'],
#  '1266': ['橁', '笋', '箰', '𥯗'],
#  '1267': ['㚨',
#   '㭄',
#   '䒖',
#   '卂',
#   '扟',
#   '汛',
#   '籸',
#   '讯',
#   '讯',
#   '軐',
#   '迅',
#   '阠',
#   '鳵',
#   '𤜢',
#   '𤣲',
#   '𤬫',
#   '𥃴',
#   '𧮬',
#   '𧿅',
#   '𩑓'],
#  '1268': ['伩', '信'],
#  '1269': ['䪿', '囟', '硇', '𱂶', '𦤟'],
#  '127': ['之', '芝'],
#  '1270': ['僎', '噀', '巽', '撰', '簨', '𬤥', '选', '选', '顨', '馔', '𩕧'],
#  '1271': ['纯', '莼'],
#  '1272': ['唇', '漘', '脣'],
#  '1273': ['瞬', '舜', '蕣'],
#  '1274': ['嵩'],
#  '1275': ['㧲', '䊉', '䫅', '俕', '宋', '浨', '筞', '𠳼', '𥒬', '𦯕'],
#  '1276': ['㮸', '送', '鎹', '𩠌', '𢱤', '𦷴', '𩠌'],
#  '1277': ['㓽', '崇', '漴', '𧽧', '𩅃', '𪉻'],
#  '1278': ['㻭',
#   '䔞',
#   '䢦',
#   '摔',
#   '率',
#   '𫄴',
#   '膟',
#   '蟀',
#   '𠌭',
#   '𠞩',
#   '𠻜',
#   '𢕑',
#   '𢟳',
#   '𣘚',
#   '𣼧',
#   '𤗪',
#   '𥡢',
#   '𦆾',
#   '𧗿',
#   '𧜠',
#   '𨄮',
#   '𩘱',
#   '𪅄',
#   '𪖶'],
#  '1279': ['㖅', '䢕', '䬄', '戌', '岁', '烕', '珬', '𣧵', '𤇳', '𧻗'],
#  '128': ['咨', '谘', '谘', '趦', '𢱆', '𣯃', '𨍢', '𨩲'],
#  '1280': ['甩', '𫝺'],
#  '1281': ['怵', '朮', '术', '杀', '沭', '秫', '术', '𰵓', '述', '𬬸'],
#  '1282': ['咑', '打', '𨴆'],
#  '1283': ['他', '咃', '怹'],
#  '1284': ['歹', '死', '薤', '飱'],
#  '1285': ['歺', '𣦵', '𣦼', '𦍲'],
#  '1286': ['戴', '瀻', '襶'],
#  '1287': ['𰊂', '带', '带', '𰑵', '𰔇', '𣨼', '滞', '蔕', '䗖', '𰸚', '𰻆', '𦄂'],
#  '1287A': ['𰒒'],
#  '1288': ['大', '奈', '套', '庆', '忕', '杕', '柰', '汏', '耷', '轪', '𰽘', '驮', '𠀤'],
#  '1288A': ['态'],
#  '1289': ['呔',
#   '太',
#   '忲',
#   '态',
#   '汰',
#   '粏',
#   '肽',
#   '舦',
#   '𮷗',
#   '迏',
#   '酞',
#   '钛',
#   '钛',
#   '駄',
#   '𥫵',
#   '𪐥'],
#  '129': ['𰨳', '𫞚', '𰱱', '资', '𥼻', '𧹌'],
#  '1290': ['泰'],
#  '1291': ['㵅', '僋', '𰇲', '贪', '𥱷'],
#  '1292': ['坛',
#   '撢',
#   '潭',
#   '燂',
#   '瞫',
#   '禫',
#   '簟',
#   '坛',
#   '蕈',
#   '蟫',
#   '覃',
#   '谭',
#   '谭',
#   '𫎫',
#   '镡',
#   '镡',
#   '𱅪',
#   '𱈓',
#   '𧰘',
#   '𫎫',
#   '𱅪',
#   '𱈓'],
#  '1293': ['坛',
#   '壜',
#   '昙',
#   '昙',
#   '坛',
#   '𤃅',
#   '𬎬',
#   '𦉡',
#   '𩪺',
#   '𪓂',
#   '𪩿',
#   '𪴘',
#   '𬎬',
#   '𭗮',
#   '𲇬'],
#  '1294': ['䃅',
#   '亸',
#   '𫢸',
#   '兽',
#   '𰅦',
#   '单',
#   '啴',
#   '单',
#   '啴',
#   '亸',
#   '𫮃',
#   '婵',
#   '婵',
#   '幝',
#   '弹',
#   '弹',
#   '惮',
#   '惮',
#   '战',
#   '戦',
#   '战',
#   '掸',
#   '掸',
#   '椫',
#   '椫',
#   '殚',
#   '殚',
#   '𬊤',
#   '兽',
#   '瘅',
#   '瘅',
#   '䃅',
#   '禅',
#   '禅',
#   '箪',
#   '箪',
#   '𦈎',
#   '蕇',
#   '蝉',
#   '蝉',
#   '褝',
#   '褝',
#   '觯',
#   '觯',
#   '辴',
#   '郸',
#   '郸',
#   '阐',
#   '阐',
#   '𱅛',
#   '𬶛',
#   '鼍',
#   '鼍',
#   '𡅄',
#   '𢧐',
#   '𤾺',
#   '𦈎',
#   '𫢸',
#   '𫮃',
#   '𬊤',
#   '𬶛',
#   '𰅦',
#   '𱅛'],
#  '1295': ['丹', '坍', '奍', '彤', '旃', '栴'],
#  '1296': ['㡺',
#   '㫜',
#   '𬘜',
#   '䖧',
#   '䜥',
#   '䞡',
#   '䦔',
#   '𱇞',
#   '䵣',
#   '亱',
#   '但',
#   '呾',
#   '坦',
#   '妲',
#   '怛',
#   '担',
#   '旦',
#   '柦',
#   '泹',
#   '炟',
#   '狚',
#   '疍',
#   '疸',
#   '笪',
#   '胆',
#   '袒',
#   '觛',
#   '詚',
#   '钽',
#   '钽',
#   '靼',
#   '𱉗',
#   '鼌',
#   '鼌',
#   '𠛣',
#   '𠡎',
#   '𢘇',
#   '𣇇',
#   '𤇁',
#   '𥅃',
#   '𥑲',
#   '𥘵',
#   '𦊥',
#   '𦤾',
#   '𦨪',
#   '𦬹',
#   '䜥',
#   '𨀏',
#   '𨈱',
#   '𨠚',
#   '𩈍',
#   '𩑰',
#   '𪪤',
#   '𫅑',
#   '𬇀',
#   '𬘜',
#   '𭖌',
#   '𭤘',
#   '𮙻',
#   '𰅊',
#   '𰐔',
#   '𱇞',
#   '𱈣',
#   '𱉗',
#   '𱐖'],
#  '1297': ['蛋'],
#  '1298': ['云',
#   '亶',
#   '儃',
#   '勯',
#   '坛',
#   '坛',
#   '嬗',
#   '擅',
#   '旜',
#   '檀',
#   '毡',
#   '毡',
#   '氊',
#   '澶',
#   '皽',
#   '羶',
#   '膻',
#   '蟺',
#   '襢',
#   '邅',
#   '颤',
#   '颤',
#   '𫗴',
#   '鳣',
#   '鳣',
#   '鹯',
#   '鹯',
#   '𤺺',
#   '𦒜',
#   '𫗴'],
#  '1299': ['忐', '忑'],
#  '13': ['㜁',
#   '喳',
#   '嵖',
#   '揸',
#   '查',
#   '査',
#   '楂',
#   '渣',
#   '猹',
#   '皶',
#   '碴',
#   '蹅',
#   '馇',
#   '馇',
#   '齄',
#   '𣉎',
#   '𥻗',
#   '𦉆',
#   '𦳘',
#   '𬭠',
#   '𩮎',
#   '𪃵',
#   '𪙁',
#   '𬊩',
#   '𬠜',
#   '𬭠',
#   '𮅤',
#   '𮖕',
#   '𰪈',
#   '𰶪',
#   '𱑟',
#   '𱚼',
#   '𱞬',
#   '𱼍'],
#  '130': ['伎',
#   '吱',
#   '妓',
#   '屐',
#   '岐',
#   '庋',
#   '忮',
#   '技',
#   '支',
#   '枝',
#   '歧',
#   '翄',
#   '翅',
#   '肢',
#   '芰',
#   '蚑',
#   '豉',
#   '跂',
#   '𫠆',
#   '𫛛',
#   '𡰸'],
#  '1300': ['炭', '碳', '羰'],
#  '1301': ['剳', '匒', '嗒', '塔', '搭', '溚', '畣', '瘩', '荅', '褡', '鞳'],
#  '1302': ['劄', '答', '箚', '荅'],
#  '1303': ['㛥',
#   '㧺',
#   '㭼',
#   '㹺',
#   '䂿',
#   '䈋',
#   '䍝',
#   '䓠',
#   '䵬',
#   '䶁',
#   '崉',
#   '沓',
#   '涾',
#   '濌',
#   '𰵸',
#   '踏',
#   '𰾓',
#   '鞜',
#   '𠉤',
#   '𠴲',
#   '𢃕',
#   '𤿽',
#   '𦧟',
#   '𦧥',
#   '𨌭',
#   '𨓬',
#   '𨡍',
#   '𨵝',
#   '𩎽',
#   '𩣯',
#   '𩭣',
#   '𪂌'],
#  '1304': ['眔', '遝', '𣝋'],
#  '1304A': ['嚃'],
#  '1305': ['㲩',
#   '䈳',
#   '𦈖',
#   '䑽',
#   '䪚',
#   '傝',
#   '塌',
#   '搨',
#   '榻',
#   '毾',
#   '溻',
#   '禢',
#   '褟',
#   '蹋',
#   '遢',
#   '𰾬',
#   '阘',
#   '阘',
#   '鳎',
#   '鳎',
#   '𠞈',
#   '𦈖',
#   '𦐇',
#   '𰾬'],
#  '1306': ['哒', '挞', '𫄤', '荙', '达', '达', '𫟼', '闼', '鞑'],
#  '1307': ['㪆',
#   '㲳',
#   '䍕',
#   '䑛',
#   '䟡',
#   '䢑',
#   '䩚',
#   '𬲮',
#   '低',
#   '厎',
#   '呧',
#   '坻',
#   '奃',
#   '岻',
#   '底',
#   '弤',
#   '彽',
#   '怟',
#   '抵',
#   '柢',
#   '氐',
#   '泜',
#   '牴',
#   '疷',
#   '眡',
#   '砥',
#   '祗',
#   '秪',
#   '羝',
#   '胝',
#   '茋',
#   '蚳',
#   '袛',
#   '觝',
#   '诋',
#   '诋',
#   '𰷢',
#   '趆',
#   '𰺀',
#   '邸',
#   '阺',
#   '骶',
#   '鸱',
#   '鸱',
#   '𡛜',
#   '𨠏',
#   '𩑾'],
#  '1308': ['啇', '啻', '啼', '帝', '揥', '碲', '禘', '缔', '蒂', '谛', '蹄', '遆'],
#  '1308A': ['膪'],
#  '1309': ['嚔', '懥', '疐', '𤴡'],
#  '131': ['卮', '巵', '栀'],
#  '1310': ['剃',
#   '娣',
#   '弟',
#   '悌',
#   '晜',
#   '梯',
#   '涕',
#   '睇',
#   '稊',
#   '第',
#   '绨',
#   '豑',
#   '递',
#   '锑',
#   '鬀',
#   '鹈',
#   '𨁃'],
#  '1311': ['替', '鐟'],
#  '1312': ['乇', '侂', '咤', '宅', '托', '秅', '讬', '饦'],
#  '1312A': ['德'],
#  '1313': ['㝵', '得', '淂', '碍', '锝'],
#  '1314': ['凼', '氹'],
#  '1315': ['㔁',
#   '㡧',
#   '㲪',
#   '㽅',
#   '䆸',
#   '䔲',
#   '䗳',
#   '䙞',
#   '䮴',
#   '䳾',
#   '僜',
#   '凳',
#   '噔',
#   '墱',
#   '嬁',
#   '嶝',
#   '憕',
#   '撜',
#   '橙',
#   '澄',
#   '灯',
#   '灯',
#   '璒',
#   '登',
#   '瞪',
#   '磴',
#   '竳',
#   '簦',
#   '膯',
#   '艠',
#   '𬢔',
#   '証',
#   '证',
#   '证',
#   '豋',
#   '蹬',
#   '邆',
#   '邒',
#   '邓',
#   '邓',
#   '镫',
#   '镫',
#   '隥',
#   '霯',
#   '鼟',
#   '𬢔'],
#  '1316': ['滕', '籐', '藤'],
#  '1317': ['㟮',
#   '㻠',
#   '揬',
#   '湥',
#   '突',
#   '葖',
#   '𱊖',
#   '鼵',
#   '𠸂',
#   '𢝀',
#   '𣔻',
#   '𤟪',
#   '𤷿',
#   '𥯝',
#   '𦔅',
#   '𦝬',
#   '𦩤',
#   '𧛗',
#   '𨨷'],
#  '1318': ['凸'],
#  '1319': ['㨮', '兜', '篼', '蔸', '𣘛', '𩮷'],
#  '132': ['㽧',
#   '䈘',
#   '兹',
#   '嗞',
#   '孳',
#   '嵫',
#   '慈',
#   '滋',
#   '玆',
#   '甆',
#   '磁',
#   '禌',
#   '稵',
#   '糍',
#   '兹',
#   '螆',
#   '镃',
#   '镃',
#   '𫚤',
#   '鶿',
#   '鹚',
#   '鹚',
#   '𠧦',
#   '𡙛',
#   '𡙠',
#   '𡞰',
#   '𢰩',
#   '𣕜',
#   '𤍏',
#   '𤧹',
#   '𤮀',
#   '𤲸',
#   '𥔵',
#   '𦔒',
#   '𦖺',
#   '𧛏',
#   '𩝐',
#   '𪑿',
#   '𫚤',
#   '𬗭',
#   '𬝘',
#   '𬹪',
#   '𭵝',
#   '𰊊'],
#  '1320': ['䇆', '呌', '头', '抖', '斗', '料', '斝', '枓', '蚪', '阧', '鬦'],
#  '1321': ['䰗', '斗', '閙', '闹', '阄', '斗', '鬦', '闹', '鬪', '鬬', '鬭', '阄'],
#  '1322': ['䖒',
#   '壴',
#   '头',
#   '痘',
#   '短',
#   '竖',
#   '竖',
#   '脰',
#   '荳',
#   '裋',
#   '豆',
#   '岂',
#   '竖',
#   '逗',
#   '鋀',
#   '头',
#   '饾',
#   '𭔰'],
#  '1323': ['㞘',
#   '㧻',
#   '䐁',
#   '䦠',
#   '冢',
#   '啄',
#   '椓',
#   '涿',
#   '琢',
#   '瘃',
#   '硺',
#   '诼',
#   '诼',
#   '豖',
#   '𧰵',
#   '𧼙',
#   '𨁿',
#   '𨧧'],
#  '1324': ['斲', '斵', '𠁁', '𤃮', '𧞐'],
#  '1325': ['啲', '的', '菂', '𩭲'],
#  '1326': ['啇', '嘀', '嫡', '摘', '敌', '敌', '滴', '谪', '豴', '蹢', '适', '镝'],
#  '1327': ['戳',
#   '擢',
#   '曜',
#   '櫂',
#   '濯',
#   '燿',
#   '籊',
#   '籴',
#   '粜',
#   '籴',
#   '粜',
#   '翟',
#   '耀',
#   '藋',
#   '趯',
#   '跃',
#   '跃'],
#  '1328': ['䯼', '唙', '悐', '梑', '狄', '荻', '逖'],
#  '1329': ['忒', '铽'],
#  '133': ['㲛',
#   '䓡',
#   '䝷',
#   '䣽',
#   '倁',
#   '智',
#   '椥',
#   '痴',
#   '知',
#   '蜘',
#   '踟',
#   '𱌄',
#   '𢛍',
#   '𥇭',
#   '𦝔',
#   '𪑜'],
#  '1330': ['店', '惦', '掂', '踮', '𠶧'],
#  '1331': ['忝', '悿', '添', '舔'],
#  '1332': ['恬', '憇', '甛', '甜', '铦', '𱃺'],
#  '1333': ['巅', '𭣇', '癫', '颠', '𠑘', '𫬟', '𣪀', '𧄺', '𬧚'],
#  '1334': ['㥏', '典', '捵', '淟', '碘', '腆', '觍', '𧡝'],
#  '1335': ['殿', '淀', '淀', '癜', '臀'],
#  '1336': ['奠', '郑', '郑'],
#  '1337': ['吞', '呑', '天', '忝', '祅', '蚕', '𡗤', '𣓁'],
#  '1338': ['殄', '餮'],
#  '1339': ['亩', '佃', '备', '田', '甸', '畋', '钿'],
#  '134': ['仔', '囝', '子', '孑', '孓', '孖', '字', '孜', '籽', '耔', '虸', '𡤼'],
#  '1340': ['丁',
#   '亭',
#   '仃',
#   '升',
#   '厅',
#   '叮',
#   '奵',
#   '宁',
#   '成',
#   '打',
#   '正',
#   '汀',
#   '灯',
#   '玎',
#   '町',
#   '疔',
#   '盯',
#   '矴',
#   '订',
#   '邒',
#   '酊',
#   '钉',
#   '靪',
#   '顶',
#   '饤'],
#  '1341': ['檙', '濎', '薡', '𰾸', '鼎', '鼏', '鼑', '𠘋', '𤐣', '𩆆', '𪔂', '𪔅'],
#  '1342': ['䘺', '定', '椗', '淀', '碇', '绽', '锭', '靛'],
#  '1343': ['㕔', '厅', '厛', '听', '厅', '聼', '听'],
#  '1344': ['䁎',
#   '亭',
#   '停',
#   '婷',
#   '嵉',
#   '揨',
#   '楟',
#   '渟',
#   '碠',
#   '葶',
#   '𢾊',
#   '𣂳',
#   '𣂴',
#   '𤗞',
#   '𥯢',
#   '𦝞',
#   '𧶺',
#   '𨉬',
#   '𩨆',
#   '𩨆',
#   '𪑬'],
#  '1345': ['庭',
#   '廷',
#   '挺',
#   '梃',
#   '珽',
#   '筳',
#   '脡',
#   '艇',
#   '莛',
#   '蜓',
#   '铤',
#   '霆',
#   '颋',
#   '𢌜'],
#  '1346': ['呈', '壬', '征'],
#  '1346A': ['廷'],
#  '1346B': ['听'],
#  '1347': ['𢶣', '𬇇', '叠', '曡', '氎', '疉', '叠', '迭', '𢶣', '𤴁', '𬇇'],
#  '1348': ['戜', '𢧜'],
#  '1348A': ['鉄', '铁', '𬴋'],
#  '1349': ['刁', '叼'],
#  '135': ['之',
#   '企',
#   '卸',
#   '址',
#   '寺',
#   '岁',
#   '徙',
#   '耻',
#   '扯',
#   '止',
#   '此',
#   '歬',
#   '歰',
#   '岁',
#   '沚',
#   '祉',
#   '耻',
#   '芷',
#   '趾',
#   '阯',
#   '齿',
#   '齿',
#   '𤴡'],
#  '1350': ['丢', '丢', '铥', '铥', '𠲍'],
#  '1351': ['吊', '屌', '弔'],
#  '1352': ['条', '条', '涤', '篠', '绦', '蓧', '鲦'],
#  '1353': ['兔', '刀', '刁', '初', '叨', '召', '忉', '舠', '𠮦'],
#  '1353A': ['到', '钊', '𠜶'],
#  '1353B': ['倒'],
#  '1354': ['嘟', '都', '𥳉', '𦡄', '𦺥', '𧷿'],
#  '1355': ['㠀', '岛', '捣'],
#  '1356': ['盗'],
#  '1357': ['导', '导', '道'],
#  '1358': ['弢'],
#  '1358A': ['讨'],
#  '1359': ['吐', '土', '杜', '灶', '肚', '芏', '走', '钍'],
#  '136': ['恉', '指', '旨', '稽', '耆', '脂', '诣', '酯', '𮬜'],
#  '1360': ['㝹',
#   '㭸',
#   '䖘',
#   '䨲',
#   '兎',
#   '兔',
#   '冤',
#   '堍',
#   '婏',
#   '寃',
#   '菟',
#   '逸',
#   '𱊆',
#   '𠒢',
#   '𠓗',
#   '𢉕',
#   '𩆟',
#   '𩣮'],
#  '1361': ['套', '𣺮'],
#  '1362': ['匋',
#   '啕',
#   '掏',
#   '淘',
#   '祹',
#   '绹',
#   '绹',
#   '萄',
#   '裪',
#   '醄',
#   '𰾏',
#   '陶',
#   '𫘦',
#   '𡍒',
#   '𢔇',
#   '𨌨',
#   '𩋃',
#   '𪌼'],
#  '1363': ['涂', '涂', '溆', '蒤', '𥂋'],
#  '1364': ['啚', '图', '圕', '图'],
#  '1365': ['䵙',
#   '侈',
#   '哆',
#   '嗲',
#   '多',
#   '奓',
#   '恀',
#   '拸',
#   '爹',
#   '眵',
#   '移',
#   '𰵥',
#   '趍',
#   '迻',
#   '黟',
#   '𡖲'],
#  '1366': ['刴', '剁', '垛', '垜', '朵', '朶', '跥', '跺', '躱', '躲', '𥞛'],
#  '1367': ['㨊',
#   '㻟',
#   '䙃',
#   '𰾖',
#   '𬳅',
#   '䯝',
#   '堶',
#   '媠',
#   '惰',
#   '楕',
#   '毻',
#   '遀',
#   '陏',
#   '隋',
#   '鬌',
#   '鰖',
#   '𣮲',
#   '𣷿',
#   '𤌃',
#   '𤭨',
#   '𥓿',
#   '𥚨',
#   '𦝦',
#   '𧤓',
#   '𧩭',
#   '𧱫',
#   '𨲕',
#   '𫪳',
#   '𬳅',
#   '𰾖'],
#  '1368': ['也',
#   '佗',
#   '坨',
#   '它',
#   '拕',
#   '柁',
#   '沱',
#   '砣',
#   '𰬉',
#   '舵',
#   '虵',
#   '蛇',
#   '𫍡',
#   '跎',
#   '酡',
#   '铊',
#   '陀',
#   '驼',
#   '𬶍',
#   '鸵',
#   '鼧'],
#  '1369': ['㞂',
#   '㟎',
#   '㱣',
#   '㼏',
#   '䅑',
#   '䧌',
#   '俀',
#   '哸',
#   '妥',
#   '娞',
#   '挼',
#   '桵',
#   '浽',
#   '绥',
#   '绥',
#   '脮',
#   '荽',
#   '鋖',
#   '鞖',
#   '馁',
#   '骽',
#   '𱉻',
#   '𡖲',
#   '𣮄',
#   '𨁡',
#   '𩗔',
#   '𩭏'],
#  '137': ['黹', '𣚠', '𧝉', '𨬚'],
#  '1370': ['䒫',
#   '代',
#   '垈',
#   '岱',
#   '帒',
#   '柋',
#   '牮',
#   '玳',
#   '笩',
#   '袋',
#   '贷',
#   '贷',
#   '鴏',
#   '黛',
#   '𠍜',
#   '𠰺',
#   '𢎌',
#   '𢘋',
#   '𥿝',
#   '𨥶',
#   '𩃷'],
#  '1371': ['㣥', '偫', '崻', '待', '𤚟'],
#  '1372': ['㥆',
#   '㻖',
#   '䇐',
#   '䠈',
#   '埭',
#   '捸',
#   '棣',
#   '殔',
#   '聿',
#   '逮',
#   '隶',
#   '隷',
#   '隶',
#   '霴',
#   '齂',
#   '𣇨'],
#  '1372A': ['肂', '肆'],
#  '1373': ['㣍',
#   '佁',
#   '冶',
#   '台',
#   '咍',
#   '始',
#   '怠',
#   '怡',
#   '抬',
#   '枱',
#   '枲',
#   '殆',
#   '殶',
#   '治',
#   '炱',
#   '眙',
#   '笞',
#   '绐',
#   '胎',
#   '苔',
#   '诒',
#   '贻',
#   '跆',
#   '迨',
#   '邰',
#   '𬭀',
#   '台',
#   '饴',
#   '骀',
#   '鲐',
#   '𱌯',
#   '𣗻'],
#  '1374': ['㘆',
#   '儓',
#   '台',
#   '嬯',
#   '懛',
#   '擡',
#   '台',
#   '籉',
#   '台',
#   '薹',
#   '𡽩',
#   '𭘚',
#   '𤁅',
#   '𤐽',
#   '𤗿',
#   '𤢬',
#   '𤻡',
#   '𦢀',
#   '𧭏',
#   '𩦽',
#   '𪒴',
#   '𭨉'],
#  '1375': ['度', '庹', '渡', '踱', '镀'],
#  '1376': ['橐', '螙', '蠧', '蠹', '𥑟', '𧉓'],
#  '1377': ['当', '当', '挡', '档', '珰', '当', '筜', '裆', '铛'],
#  '1378': ['傥', '党', '𫽮', '𭧋', '𰥹', '谠', '党'],
#  '1379': ['宕', '菪', '趤', '𥒳'],
#  '138': ['姉', '姊', '巿', '杮', '柹'],
#  '1380': ['汤',
#   '汤',
#   '烫',
#   '烫',
#   '𬍡',
#   '荡',
#   '𰩹',
#   '荡',
#   '荡',
#   '铴',
#   '铴',
#   '𡾕',
#   '𢡂',
#   '𢴳',
#   '𬍡',
#   '𰩹'],
#  '1380A': ['蘯', '𢥉', '𥗔'],
#  '1381': ['傏', '唐', '塘', '搪', '榶', '溏', '糖', '螗', '醣', '𬳍'],
#  '1382': ['堂', '瞠', '膛', '螳', '蹚', '镗', '鼞', '𨝦'],
#  '1383': ['㙐',
#   '㟨',
#   '㪜',
#   '㼷',
#   '䳪',
#   '䵎',
#   '偳',
#   '剬',
#   '喘',
#   '圌',
#   '媏',
#   '惴',
#   '揣',
#   '椯',
#   '歂',
#   '湍',
#   '煓',
#   '猯',
#   '瑞',
#   '端',
#   '篅',
#   '耑',
#   '腨',
#   '褍',
#   '𫍱',
#   '貒',
#   '踹',
#   '𰺒',
#   '遄',
#   '𰾜',
#   '颛',
#   '颛',
#   '𥠄',
#   '𬥼',
#   '𧼴',
#   '𩠊',
#   '𩤚'],
#  '1383A': ['短'],
#  '1384': ['段', '毈', '煅', '碫', '缎', '腶', '锻'],
#  '1385': ['㝄',
#   '㹠',
#   '㼊',
#   '䣩',
#   '伅',
#   '吨',
#   '吨',
#   '囤',
#   '屯',
#   '庉',
#   '忳',
#   '扽',
#   '旾',
#   '杶',
#   '沌',
#   '炖',
#   '盹',
#   '砘',
#   '窀',
#   '纯',
#   '纯',
#   '肫',
#   '芚',
#   '豘',
#   '𰹸',
#   '迍',
#   '邨',
#   '钝',
#   '钝',
#   '霕',
#   '顿',
#   '顿',
#   '饨',
#   '鲀',
#   '黗',
#   '𡗥',
#   '𤵊',
#   '𥫱',
#   '𥸵',
#   '𨳘',
#   '𩂄',
#   '𩖤',
#   '𪌋',
#   '𪎶'],
#  '1386': ['㩛', '团', '团', '团'],
#  '1387': ['豚', '遯', '𧲝'],
#  '1388': ['断', '断', '簖'],
#  '1388A': ['夺', '夺'],
#  '1389': ['帅', '师', '帅', '师', '追', '𠂤'],
#  '139': ['䪡', '姊', '柹', '泲', '秭', '笫', '第', '胏', '𠂔'],
#  '1390': ['㠚',
#   '㦠',
#   '𬀮',
#   '㳔',
#   '𱁒',
#   '嚉',
#   '对',
#   '对',
#   '怼',
#   '㳔',
#   '𰰱',
#   '𰳸',
#   '譵',
#   '𰺃',
#   '鑆',
#   '𨮝',
#   '𬀮',
#   '𰰱',
#   '𰳸',
#   '𰺃',
#   '𱁒'],
#  '1391': ['坠', '队', '队'],
#  '1392': ['兊',
#   '兑',
#   '帨',
#   '悦',
#   '悦',
#   '捝',
#   '捝',
#   '棁',
#   '棁',
#   '涗',
#   '涚',
#   '税',
#   '税',
#   '脱',
#   '脱',
#   '蜕',
#   '蜕',
#   '裞',
#   '说',
#   '说',
#   '锐',
#   '阅',
#   '阅',
#   '𱅙'],
#  '1393': ['㔼', '嶊', '推', '蓷', '𤍐'],
#  '1394': ['㾼', '煺', '腿', '褪', '蹆', '退', '𠺙', '𩄮'],
#  '1395': ['㱩',
#   '𰂏',
#   '𰃿',
#   '𰅥',
#   '卖',
#   '𪥿',
#   '椟',
#   '椟',
#   '㱩',
#   '渎',
#   '渎',
#   '牍',
#   '牍',
#   '犊',
#   '犊',
#   '窦',
#   '窦',
#   '续',
#   '续',
#   '𰱐',
#   '觌',
#   '觌',
#   '读',
#   '𮙋',
#   '读',
#   '卖',
#   '赎',
#   '赎',
#   '𱁷',
#   '黩',
#   '黩',
#   '𬑙',
#   '𪥿',
#   '𮙋',
#   '𰂏',
#   '𰃿',
#   '𰅥',
#   '𰱐',
#   '𱁷'],
#  '1396': ['䓯', '毒', '瑇', '碡', '纛', '𠉩', '𠒾', '𢝂', '𤚚', '𧛔'],
#  '1397': ['秃', '秃', '𬓼', '鋵', '颓', '𪉍'],
#  '1398': ['䃦',
#   '䔻',
#   '䪃',
#   '噋',
#   '墩',
#   '墪',
#   '憝',
#   '憞',
#   '撉',
#   '撴',
#   '敦',
#   '暾',
#   '橔',
#   '潡',
#   '燉',
#   '獤',
#   '礅',
#   '𬤣',
#   '蹾',
#   '镦',
#   '鐜',
#   '镦',
#   '𮪥',
#   '鷻',
#   '𠓎',
#   '𡼖',
#   '𥂦',
#   '𦪔',
#   '𧝋',
#   '𧝗'],
#  '1399': ['吨', '噋', '顿'],
#  '14': ['嗏', '搽', '茶'],
#  '140': ['只', '咫', '枳', '胑', '轵', '𱌫'],
#  '1400': ['㑰',
#   '㥟',
#   '䂕',
#   '䞼',
#   '𰾦',
#   '䧘',
#   '喙',
#   '彖',
#   '掾',
#   '椽',
#   '湪',
#   '猭',
#   '瑑',
#   '盠',
#   '禒',
#   '篆',
#   '缘',
#   '缘',
#   '腞',
#   '蒃',
#   '蝝',
#   '蠡',
#   '褖',
#   '𱄄',
#   '𢐄',
#   '𣂵',
#   '𣨶',
#   '𤬌',
#   '𤸁',
#   '𦧬',
#   '𧳩',
#   '𨂦',
#   '𩄖',
#   '𩔂'],
#  '1401': ['循', '揗', '楯', '盾', '腯', '𮝸', '遁'],
#  '1402': ['佟', '冬', '氡', '疼', '终', '冬'],
#  '1403': ['䵔', '东', '冻', '东', '栋', '𰛒', '𬟽', '陈', '鸫', '𧯾'],
#  '1404': ['嬞', '懂', '董', '𣿅', '𦡂', '𧄓'],
#  '1405': ['𫢙', '动', '动', '恸'],
#  '1406': ['僮',
#   '幢',
#   '憧',
#   '撞',
#   '曈',
#   '朣',
#   '橦',
#   '潼',
#   '獞',
#   '疃',
#   '瞳',
#   '穜',
#   '童',
#   '罿',
#   '艟',
#   '鈡',
#   '钟',
#   '𠟍'],
#  '1407': ['㓊',
#   '㢥',
#   '㣚',
#   '㸗',
#   '䞒',
#   '仝',
#   '侗',
#   '兴',
#   '同',
#   '哃',
#   '姛',
#   '峒',
#   '峝',
#   '恫',
#   '戙',
#   '挏',
#   '桐',
#   '洞',
#   '烔',
#   '狪',
#   '痌',
#   '眮',
#   '硐',
#   '秱',
#   '筒',
#   '粡',
#   '𫄡',
#   '胴',
#   '兴',
#   '茼',
#   '同',
#   '迵',
#   '酮',
#   '铜',
#   '铜',
#   '餇',
#   '𩧲',
#   '鲖',
#   '𠖄',
#   '𡭸',
#   '𢈉',
#   '𢏕',
#   '𣑸',
#   '𦨴',
#   '𧇌',
#   '𧙥',
#   '𧳆',
#   '𨀜',
#   '𨈹',
#   '𨚯',
#   '𨴏',
#   '𩧲',
#   '𩩅',
#   '𪀭',
#   '𪌢'],
#  '1408': ['䌂',
#   '䠎',
#   '偓',
#   '剭',
#   '喔',
#   '媉',
#   '屋',
#   '幄',
#   '握',
#   '楃',
#   '渥',
#   '箼',
#   '腛',
#   '龌',
#   '龌',
#   '𡎔',
#   '𥟽',
#   '𨜘',
#   '𪑱'],
#  '1409': ['䨟', '洼', '洼', '𱛿'],
#  '1409A': ['呙', '𬏮', '𢝸'],
#  '141': ['侄',
#   '厔',
#   '咥',
#   '姪',
#   '室',
#   '庢',
#   '挃',
#   '李',
#   '桎',
#   '窒',
#   '绖',
#   '耊',
#   '耋',
#   '至',
#   '致',
#   '蛭',
#   '轾',
#   '郅',
#   '铚',
#   '𢎆'],
#  '1410': ['㟆',
#   '㟆',
#   '华',
#   '哗',
#   '哗',
#   '晔',
#   '晔',
#   '曅',
#   '桦',
#   '桦',
#   '烨',
#   '烨',
#   '华',
#   '蕐',
#   '譁',
#   '铧',
#   '铧',
#   '𫖇',
#   '𮧵',
#   '骅',
#   '骅',
#   '𪩓',
#   '𫖇',
#   '𮧵'],
#  '1410A': ['话'],
#  '1411': ['㗏', '歪', '𢱉', '𤟷', '𨂿'],
#  '1412': ['坏', '怀', '瓌', '瓖', '褱'],
#  '1413': ['汇', '汇', '淮', '滙'],
#  '1414': ['剨', '湱', '砉', '𬴃', '𢝇'],
#  '1415': ['划', '划', '婳', '画', '画', '畵', '𰬠', '𢄶'],
#  '1416': ['㖪',
#   '囯',
#   '囻',
#   '国',
#   '国',
#   '域',
#   '彧',
#   '惑',
#   '或',
#   '棫',
#   '淢',
#   '窢',
#   '𰬟',
#   '罭',
#   '蜮',
#   '阈',
#   '馘',
#   '魊'],
#  '1417': ['燹', '豩', '豳'],
#  '1418': ['弯', '弯', '湾', '𮱐', '𢺯', '𣡩', '𨂺'],
#  '1419': ['䁵',
#   '䚪',
#   '鹮',
#   '𫜅',
#   '不',
#   '儇',
#   '噮',
#   '圜',
#   '嬛',
#   '寰',
#   '彋',
#   '懁',
#   '擐',
#   '檈',
#   '澴',
#   '獧',
#   '环',
#   '环',
#   '癏',
#   '睘',
#   '瞏',
#   '糫',
#   '缳',
#   '缳',
#   '翾',
#   '蠉',
#   '𫍽',
#   '𮝹',
#   '还',
#   '还',
#   '镮',
#   '镮',
#   '阛',
#   '阛',
#   '鬟',
#   '𬶵',
#   '鹮',
#   '𠟼',
#   '𫍽',
#   '𫜅',
#   '𬶵',
#   '𮝹'],
#  '142': ['㨖', '㮹', '㴛', '䞃', '𫔵', '致', '致', '𤸓', '𥠽', '𦟔', '𦥐', '𧛢', '𩋩'],
#  '1420': ['㘭', '䒛', '幻', '抝'],
#  '1421': ['患', '槵', '漶', '瞣', '𧹗', '𢡃', '𤡟', '𧴊', '𧹗'],
#  '1422': ['挖', '穵'],
#  '1423': ['𢯲', '𥄗'],
#  '1424': ['㙎', '喴', '威', '媙', '崴', '揻', '楲', '縅', '葳', '隇', '𦩬'],
#  '1425': ['㢻',
#   '㣦',
#   '㮃',
#   '㹻',
#   '䅗',
#   '䫋',
#   '𱃜',
#   '䰀',
#   '䴧',
#   '倭',
#   '唩',
#   '委',
#   '婑',
#   '崣',
#   '捼',
#   '涹',
#   '瓾',
#   '痿',
#   '矮',
#   '𮉫',
#   '腇',
#   '萎',
#   '覣',
#   '诿',
#   '诿',
#   '踒',
#   '躷',
#   '逶',
#   '𬭗',
#   '𫗪',
#   '魏',
#   '𡣢',
#   '𡯵',
#   '𣨙',
#   '𤉦',
#   '𥟿',
#   '𥡭',
#   '𥪍',
#   '𦓽',
#   '𨡌',
#   '𨵋'],
#  '1425A': ['卉', '泋'],
#  '1426': ['虫'],
#  '1427': ['䛼', '毁', '毁', '燬', '譭'],
#  '1428': ['㙗',
#   '㛱',
#   '㞇',
#   '㟪',
#   '㱬',
#   '㾯',
#   '𦈓',
#   '偎',
#   '喂',
#   '嵔',
#   '愄',
#   '揋',
#   '椳',
#   '渨',
#   '煨',
#   '猥',
#   '畏',
#   '碨',
#   '腲',
#   '葨',
#   '𰾚',
#   '隈',
#   '𫗭',
#   '鳂',
#   '鳂',
#   '𢉝',
#   '𣉍',
#   '𤧖',
#   '𥚸',
#   '𥯜',
#   '𦈓',
#   '𧍥',
#   '𧛚',
#   '𧤖',
#   '𧪏',
#   '𧱨',
#   '𨃄',
#   '𪉭',
#   '𪫑',
#   '𫗭',
#   '𬙒',
#   '𰾚'],
#  '1429': ['尉', '嶎', '慰', '熨', '犚', '罻', '蔚', '褽', '霨'],
#  '143': ['䏯', '䓌', '俧', '志', '梽', '痣', '𬘨', '𬢌', '志', '鋕', '𢙺', '𥭡', '𩊴', '𪁓'],
#  '1430': ['𰳚', '潍', '维', '𢣘'],
#  '1431': ['𰿫',
#   '为',
#   '伪',
#   '伪',
#   '妫',
#   '𰌷',
#   '㧑',
#   '沩',
#   '为',
#   '为',
#   '𫇭',
#   '𫇭',
#   '蘤',
#   '𰵑',
#   '𰻦',
#   '𤾸'],
#  '1432': ['䑊',
#   '䪋',
#   '𭏸',
#   '𬉋',
#   '𬤦',
#   '遗',
#   '遗',
#   '𢸦',
#   '𥌰',
#   '𧂠',
#   '𧒭',
#   '𧒭',
#   '𧞸',
#   '𧸽',
#   '𨽟',
#   '𪐔',
#   '𬉋',
#   '𬤦',
#   '𭏸'],
#  '1433': ['伟',
#   '伟',
#   '卫',
#   '围',
#   '围',
#   '帏',
#   '帏',
#   '𬀩',
#   '𣲗',
#   '炜',
#   '炜',
#   '玮',
#   '玮',
#   '祎',
#   '祎',
#   '纬',
#   '纬',
#   '苇',
#   '苇',
#   '卫',
#   '衞',
#   '袆',
#   '袆',
#   '讳',
#   '𬣀',
#   '讳',
#   '躗',
#   '违',
#   '违',
#   '郼',
#   '闱',
#   '闱',
#   '韦',
#   '韪',
#   '𮧵',
#   '韦',
#   '韪',
#   '𣲗',
#   '𤜂',
#   '𬀩',
#   '𬣀',
#   '𮧵'],
#  '1434': ['囗', '圂', '圉'],
#  '1435': ['唯', '嶉', '蓶', '𱊡', '𧐌'],
#  '1436': ['位', '涖', '莅'],
#  '1436A': ['汇'],
#  '1437': ['䧥',
#   '僡',
#   '寭',
#   '惠',
#   '憓',
#   '橞',
#   '潓',
#   '璤',
#   '穗',
#   '𰬸',
#   '蕙',
#   '蟪',
#   '𬤝',
#   '𰾶',
#   '𬰶',
#   '𠦽',
#   '𠽡',
#   '𢴥',
#   '𥛸',
#   '𦒎',
#   '𨎥',
#   '𪒜',
#   '𪱇',
#   '𫂠',
#   '𫆵',
#   '𫱮',
#   '𬋅',
#   '𬤝',
#   '𬰶',
#   '𬵪',
#   '𬺡',
#   '𮋍',
#   '𰬸',
#   '𰾶',
#   '𱜵'],
#  '1438': ['㨹',
#   '㻰',
#   '䨮',
#   '䵻',
#   '嘒',
#   '彗',
#   '慧',
#   '槥',
#   '熭',
#   '篲',
#   '蔧',
#   '𫐕',
#   '𬭬',
#   '𢄣',
#   '𢑹',
#   '𢟩',
#   '𦄑',
#   '𩏚',
#   '𪔊'],
#  '1439': ['㥜', '喟', '媦', '渭', '猬', '胃', '猬', '谓', '𩨅'],
#  '144': ['廌',
#   '荐',
#   '荐',
#   '鞯',
#   '韀',
#   '鞯',
#   '𠏰',
#   '𢖇',
#   '𢢘',
#   '𣿕',
#   '𤢒',
#   '𥴱',
#   '𦆉',
#   '𦉙',
#   '𧲊',
#   '𨷓',
#   '𪢔',
#   '𪴇',
#   '𫋡',
#   '𫬅',
#   '𫸠',
#   '𬋽',
#   '𬰟',
#   '𮣘'],
#  '1440': ['嗢',
#   '媪',
#   '媪',
#   '愠',
#   '愠',
#   '揾',
#   '揾',
#   '昷',
#   '氲',
#   '氲',
#   '温',
#   '温',
#   '煴',
#   '煴',
#   '瘟',
#   '缊',
#   '缊',
#   '腽',
#   '腽',
#   '辒',
#   '酝',
#   '酝',
#   '酝',
#   '韫',
#   '𥁕',
#   '𦤨'],
#  '1440A': ['蕴', '蕴'],
#  '1440B': ['稳'],
#  '1441': ['䢵',
#   '䰟',
#   '𪉂',
#   '云',
#   '伝',
#   '呍',
#   '囩',
#   '坛',
#   '夽',
#   '妘',
#   '层',
#   '忶',
#   '抎',
#   '枟',
#   '眃',
#   '秐',
#   '纭',
#   '纭',
#   '耘',
#   '耺',
#   '芸',
#   '运',
#   '云',
#   '魂',
#   '𪉂'],
#  '1441A': ['昙', '昙', '沄', '沄', '芸', '芸'],
#  '1442': ['匀', '匀', '均', '昀', '畇', '袀', '訇', '钧', '韵'],
#  '1443': ['䪳', '伊', '吚', '君', '尹', '笋', '芛', '𡱉', '𤣹', '𧉅', '𨊼', '𩉥', '𩨫'],
#  '1444': ['乆', '允', '吮', '夋', '沇', '狁', '𠃔'],
#  '1445': ['㥵', '㨡', '㮯', '圂', '慁', '溷', '𦞢', '𦵣', '𨍲'],
#  '1446': ['䡏', '䨎', '宖', '弘', '泓', '𰬋', '苰', '鞃', '𠰈', '𢘌', '𬭂'],
#  '1447': ['宏', '峵', '浤', '硡', '竤', '𫟄', '𬭎', '𥏕', '𨌆'],
#  '1448': ['䖇', '欝', '灪', '爩', '郁', '郁', '𡿥', '𢺴', '𥘄', '𪓊'],
#  '1449': ['㭾',
#   '㻕',
#   '䓛',
#   '䘿',
#   '䞷',
#   '䠇',
#   '倔',
#   '啒',
#   '堀',
#   '屈',
#   '崛',
#   '崫',
#   '掘',
#   '淈',
#   '煀',
#   '窟',
#   '𫍮',
#   '镼',
#   '𫛵',
#   '𠜾',
#   '𢏷',
#   '𣨢',
#   '𣮈',
#   '𤟎',
#   '𥏘',
#   '𥪊',
#   '𥮝',
#   '𥺷',
#   '𦁐',
#   '𦜇',
#   '𧌑',
#   '𨱊',
#   '𨱊',
#   '𨵡',
#   '𩓦',
#   '𩣹',
#   '𪘳'],
#  '145': ['𰬛', '豸'],
#  '1450': ['䆷',
#   '䤎',
#   '䰬',
#   '僪',
# ...
#   '𦡚',
#   '𧒱',
#   '𧝸',
#   '𧴗',
#   '𩆄',
#   '𩍓',
#   '𩏨',
#   '𬳓',
#   '𪇉',
#   '𪖿',
#   '𬆳',
#   '𬐷',
#   '𬪘',
#   '𬬑',
#   '𬳓',
#   '𭬎',
#   '𲁅'],
#  '1653': ['㜉',
#   '㴩',
#   '嗈',
#   '邕',
#   '郺',
#   '雝',
#   '齆',
#   '𢀍',
#   '𦃽',
#   '𦞡',
#   '𨝖',
#   '𨞑',
#   '𪄉',
#   '𪪝'],
#  '1653A': ['廱', '灉', '痈', '痈'],
#  '1654': ['㮬',
#   '㺋',
#   '䈵',
#   '䐥',
#   '䩺',
#   '𮬢',
#   '傟',
#   '嗡',
#   '嵡',
#   '慃',
#   '暡',
#   '滃',
#   '瞈',
#   '翁',
#   '蓊',
#   '螉',
#   '𬭩',
#   '𡻐',
#   '𤌏',
#   '𥕀',
#   '𦫫',
#   '𧛹',
#   '𨜺',
#   '𩄘',
#   '𩔚',
#   '𩡓',
#   '𩮬'],
#  '1655': ['宂', '鴧'],
#  '1656': ['㣑', '佣', '佣', '墉', '庸', '慵', '鄘', '镛'],
#  '1657': ['㼸',
#   '䈶',
#   '䡥',
#   '傛',
#   '嫆',
#   '容',
#   '嵱',
#   '彮',
#   '愹',
#   '搈',
#   '榕',
#   '溶',
#   '熔',
#   '瑢',
#   '穃',
#   '蓉',
#   '褣',
#   '镕',
#   '镕',
#   '𫚦',
#   '𠹍',
#   '𦗋',
#   '𧯉',
#   '𨉷',
#   '𨲟',
#   '𩮠',
#   '𪃾'],
#  '1658': ['㲨',
#   '䠜',
#   '䤊',
#   '䩸',
#   '傇',
#   '媶',
#   '搑',
#   '榵',
#   '穁',
#   '縙',
#   '茸',
#   '𣯏',
#   '𥎂',
#   '𦔋',
#   '𧎣',
#   '𨉴',
#   '𨍷'],
#  '1659': ['㣝',
#   '㭜',
#   '䄾',
#   '䘬',
#   '䯷',
#   '娀',
#   '戎',
#   '毧',
#   '狨',
#   '绒',
#   '绒',
#   '羢',
#   '茙',
#   '𱅉',
#   '𡊸',
#   '𢫨',
#   '𥑳',
#   '𥬪',
#   '𧊕',
#   '𨠤',
#   '𨱿',
#   '𱉣'],
#  '166': ['畟', '稷', '谡'],
#  '1660': ['㛚',
#   '㦷',
#   '㪌',
#   '㼧',
#   '俑',
#   '勈',
#   '恿',
#   '悀',
#   '捅',
#   '桶',
#   '涌',
#   '甬',
#   '痛',
#   '硧',
#   '筩',
#   '蛹',
#   '诵',
#   '诵',
#   '踊',
#   '通',
#   '銿',
#   '鲬',
#   '鲬',
#   '𠳀',
#   '𡇮',
#   '𣭲',
#   '𥦁',
#   '𧗴',
#   '𧻹',
#   '𨴭',
#   '𬱥'],
#  '1660A': ['慂'],
#  '1661': ['㗈', '䞻', '勇', '愑', '湧', '踊', '𩔘'],
#  '1662': ['㶲',
#   '佣',
#   '庸',
#   '拥',
#   '用',
#   '甩',
#   '甮',
#   '痈',
#   '砽',
#   '苚',
#   '𡶤',
#   '𤰅',
#   '𥁎',
#   '𥥝',
#   '𦙸',
#   '𩬮'],
#  '167': ['陟', '𱀑', '骘'],
#  '168': ['炙'],
#  '169': ['席', '度', '庶', '蓆', '褯'],
#  '16A': ['䊮', '䴞', '嚁', '翟', '𱊱', '𡽢'],
#  '17': ['㤞',
#   '䖳',
#   '𬭈',
#   '䯔',
#   '侘',
#   '咤',
#   '垞',
#   '姹',
#   '宅',
#   '挓',
#   '烢',
#   '秺',
#   '诧',
#   '诧',
#   '𤞌',
#   '𤵾',
#   '𥭌',
#   '𨀸',
#   '𩢵',
#   '𩽽',
#   '𪀥'],
#  '170': ['亱', '匇', '夕', '外', '夘', '夙', '多', '夜', '汐', '矽', '穸', '𡿪'],
#  '171': ['値', '值', '埴', '德', '悳', '惪', '植', '殖', '犆', '直', '矗', '稙', '置'],
#  '172': ['借', '稓', '籍', '借'],
#  '173': ['㡿', '㴑', '𣔳'],
#  '174': ['彳', '役', '得', '𢔊', '𨑠'],
#  '175': ['㗤',
#   '㞝',
#   '䗩',
#   '䙘',
#   '䠞',
#   '傶',
#   '嘁',
#   '墄',
#   '慼',
#   '慽',
#   '戚',
#   '摵',
#   '槭',
#   '磩',
#   '𦈚',
#   '蹙',
#   '𬭭',
#   '𫖹',
#   '𥉷',
#   '𦈚',
#   '𦸗'],
#  '176': ['坼', '拆', '斥', '柝', '泝', '诉', '跅', '𪉄'],
#  '176A': ['赤'],
#  '177': ['㣌',
#   '㸃',
#   '乩',
#   '佔',
#   '占',
#   '呫',
#   '坫',
#   '帖',
#   '店',
#   '怗',
#   '战',
#   '拈',
#   '敁',
#   '毡',
#   '沾',
#   '点',
#   '煔',
#   '玷',
#   '痁',
#   '砧',
#   '站',
#   '粘',
#   '苫',
#   '觇',
#   '觇',
#   '贴',
#   '贴',
#   '跕',
#   '鉆',
#   '阽',
#   '飐',
#   '飐',
#   '鲇',
#   '鲇',
#   '黏',
#   '点',
#   '𤘇'],
#  '178': ['惉', '霑', '𡝫', '𤊁', '𥮒', '𨵍', '𮏝'],
#  '179': ['㙴',
#   '㜬',
#   '䃫',
#   '䄡',
#   '䟋',
#   '䠨',
#   '䦲',
#   '𬰷',
#   '儋',
#   '噡',
#   '嶦',
#   '幨',
#   '憺',
#   '担',
#   '担',
#   '曕',
#   '檐',
#   '澹',
#   '甔',
#   '癚',
#   '瞻',
#   '簷',
#   '聸',
#   '胆',
#   '胆',
#   '舚',
#   '薝',
#   '蟾',
#   '襜',
#   '詹',
#   '谵',
#   '谵',
#   '赡',
#   '赡',
#   '韂',
#   '黵',
#   '𠓏',
#   '𠟧',
#   '𢕻',
#   '𢨕',
#   '𣀁',
#   '𤐐',
#   '𤖝',
#   '𤗻',
#   '𦅼',
#   '𦉜',
#   '𧩏',
#   '𨊍',
#   '𨎻',
#   '𨗧',
#   '𨼮',
#   '𩁏',
#   '𩟋',
#   '𪆻',
#   '𪼤',
#   '𬰷',
#   '𱃏',
#   '𱰒',
#   '𲋉'],
#  '18': ['择', '箨', '萚'],
#  '180': ['尖'],
#  '181': ['䤔', '渐', '𫆏', '魙', '𬞋', '𬰣'],
#  '182': ['㢛',
#   '𤈷',
#   '㿌',
#   '𬘪',
#   '䩎',
#   '䲓',
#   '𱌵',
#   '佥',
#   '俭',
#   '佥',
#   '俭',
#   '剑',
#   '剑',
#   '劎',
#   '劒',
#   '劔',
#   '匳',
#   '𰆚',
#   '𪡋',
#   '𫰰',
#   '崄',
#   '崄',
#   '𪫺',
#   '捡',
#   '捡',
#   '敛',
#   '敛',
#   '检',
#   '检',
#   '𰙎',
#   '殓',
#   '殓',
#   '𰛲',
#   '猃',
#   '猃',
#   '睑',
#   '睑',
#   '硷',
#   '硷',
#   '签',
#   '签',
#   '羷',
#   '脸',
#   '脸',
#   '莶',
#   '莶',
#   '裣',
#   '裣',
#   '譣',
#   '𫑷',
#   '鐱',
#   '险',
#   '险',
#   '𱂫',
#   '验',
#   '验',
#   '硷',
#   '𰉱',
#   '𤈷',
#   '𪡋',
#   '𪫺',
#   '𫑷',
#   '𫰰',
#   '𬘪',
#   '𰆚',
#   '𰉱',
#   '𰙎',
#   '𰛲',
#   '𱂫',
#   '𱌵'],
#  '183': ['千',
#   '孅',
#   '忏',
#   '忏',
#   '歼',
#   '歼',
#   '瀸',
#   '签',
#   '签',
#   '纎',
#   '纤',
#   '纤',
#   '谶',
#   '谶',
#   '韯',
#   '韱'],
#  '184': ['旃', '栴'],
#  '185': ['㟞',
#   '㣤',
#   '㥇',
#   '𫞣',
#   '䎒',
#   '䏼',
#   '𰲳',
#   '䙁',
#   '䧖',
#   '䱠',
#   '䴼',
#   '俴',
#   '刬',
#   '刬',
#   '𰏕',
#   '戋',
#   '戋',
#   '栈',
#   '栈',
#   '残',
#   '残',
#   '浅',
#   '浅',
#   '𰠛',
#   '𬍙',
#   '盏',
#   '盏',
#   '碊',
#   '笺',
#   '笺',
#   '线',
#   '线',
#   '菚',
#   '虥',
#   '𰲠',
#   '𬣡',
#   '贱',
#   '贱',
#   '践',
#   '践',
#   '𰹼',
#   '𬪨',
#   '钱',
#   '钱',
#   '饯',
#   '饯',
#   '馢',
#   '𠒲',
#   '𫞣',
#   '𬍙',
#   '𬣡',
#   '𬪨',
#   '𰏕',
#   '𰠛',
#   '𰲠',
#   '𰲳',
#   '𰹼'],
#  '186': ['羴', '羼'],
#  '187': ['冁', '展', '搌', '碾', '蹍', '辗', '𣪵'],
#  '188': ['剪', '翦', '谫'],
#  '189': ['䍎', '𰜨', '荐', '荐', '鞯', '鞯', '𥤆', '𦇩', '𧂑', '𧟆', '𧲛', '𨰂', '𨷳', '𰜨'],
#  '18A': ['拆'],
#  '19': ['㹪',
#   '册',
#   '册',
#   '删',
#   '删',
#   '姗',
#   '姗',
#   '栅',
#   '栅',
#   '珊',
#   '笧',
#   '粣',
#   '跚',
#   '𫟶',
#   '𡊢',
#   '𢦫',
#   '𣆑',
#   '𣌧',
#   '𣧱',
#   '𣫳',
#   '𤇒',
#   '𥑬',
#   '𦙱',
#   '𦙽',
#   '𧵡',
#   '𩒄',
#   '𩬥',
#   '𪑃',
#   '𪨪',
#   '𪭪',
#   '𫁠',
#   '𫚷',
#   '𫟶',
#   '𬅡',
#   '𬨡',
#   '𭇒',
#   '𮁧',
#   '𮟰',
#   '𮤊',
#   '𮱹',
#   '𮶁',
#   '𰇑',
#   '𰛚'],
#  '190': ['𮲶', '溅'],
#  '191': ['䙴', '僊', '蹮', '迁', '迁'],
#  '192': ['䀒',
#   '䊹',
#   '仟',
#   '千',
#   '扦',
#   '杄',
#   '汘',
#   '秊',
#   '粁',
#   '芊',
#   '谸',
#   '迁',
#   '钎',
#   '钎',
#   '阡',
#   '𧘜',
#   '𧮮'],
#  '193': ['䉦', '𰗬', '跹', '迁', '千'],
#  '194': ['蒇'],
#  '195': ['㕓',
#   '㙻',
#   '㢆',
#   '壥',
#   '廛',
#   '瀍',
#   '缠',
#   '纒',
#   '缠',
#   '躔',
#   '鄽',
#   '𡃚',
#   '𡏂',
#   '𢷹',
#   '𤄊',
#   '𤪮',
#   '𥌬',
#   '𧁶',
#   '𧔊',
#   '𧔹',
#   '𧸳',
#   '𧾡',
#   '𨇠',
#   '𨮻',
#   '𨷠',
#   '𩼼',
#   '𩽦',
#   '𪇮',
#   '𫑮',
#   '𮤪'],
#  '196': ['前', '剪', '揃', '椾', '歬', '湔', '煎', '箭', '翦', '鬋'],
#  '197': ['篯'],
#  '198': ['䡠',
#   '侦',
#   '侦',
#   '𰌂',
#   '寊',
#   '帧',
#   '帧',
#   '揁',
#   '桢',
#   '桢',
#   '浈',
#   '浈',
#   '碵',
#   '祯',
#   '祯',
#   '緽',
#   '贞',
#   '贞',
#   '赪',
#   '赪',
#   '遉',
#   '鍞',
#   '𠸩',
#   '𡎞',
#   '𢒟',
#   '𢔤',
#   '𤋺',
#   '𤦹',
#   '𤸘',
#   '𦵄',
#   '𧶸',
#   '𨜓',
#   '𨺟',
#   '𩹰',
#   '𪍕',
#   '𬹕',
#   '𫖙',
#   '𫖣',
#   '𫨫',
#   '𮲅',
#   '𬓲',
#   '𬡥',
#   '𬢵',
#   '𬹕',
#   '𭵐',
#   '𮛶',
#   '𮲅',
#   '𰌂',
#   '𰷺'],
#  '199': ['征', '征', '惩', '惩', '澂', '症', '症'],
#  '2': ['亚',
#   '亜',
#   '亚',
#   '哑',
#   '哑',
#   '垩',
#   '垩',
#   '壶',
#   '壸',
#   '壶',
#   '壸',
#   '娅',
#   '娅',
#   '恶',
#   '恶',
#   '挜',
#   '挜',
#   '桠',
#   '桠',
#   '氩',
#   '氩',
#   '痖',
#   '痖',
#   '铔',
#   '铔',
#   '𱉨',
#   '𱉨'],
#  '20': ['贼', '贼', '𣛸', '𣿐', '𬝠', '𨆎'],
#  '200': ['晶', '曐', '曑', '曟', '橸', '蕌', '𣊖'],
#  '201': ['㱏',
#   '䋊',
#   '佂',
#   '定',
#   '延',
#   '征',
#   '怔',
#   '政',
#   '整',
#   '是',
#   '昰',
#   '正',
#   '炡',
#   '焉',
#   '症',
#   '眐',
#   '𰩓',
#   '罡',
#   '証',
#   '证',
#   '钲',
#   '钲',
#   '鴊',
#   '𢁿',
#   '𦙫',
#   '𧘿',
#   '𨚣'],
#  '202': ['偁', '尔', '爯', '称', '𢜻'],
#  '203': ['䑶',
#   '䞍',
#   '䞍',
#   '䨝',
#   '䴖',
#   '倩',
#   '凊',
#   '啨',
#   '圊',
#   '埥',
#   '婧',
#   '寈',
#   '崝',
#   '情',
#   '掅',
#   '晴',
#   '棈',
#   '氰',
#   '淸',
#   '清',
#   '猜',
#   '皘',
#   '睛',
#   '碃',
#   '箐',
#   '精',
#   '𬘬',
#   '聙',
#   '腈',
#   '菁',
#   '蜻',
#   '请',
#   '请',
#   '𰺉',
#   '郬',
#   '锖',
#   '锖',
#   '靑',
#   '青',
#   '靓',
#   '靔',
#   '靖',
#   '靘',
#   '靓',
#   '靝',
#   '鲭',
#   '鲭',
#   '䴖',
#   '鼱',
#   '𠝜',
#   '𡸺',
#   '𢃢',
#   '𢉑',
#   '𣮛',
#   '𤦭',
#   '𤲟',
#   '𦑊',
#   '𦑖',
#   '𧚫',
#   '𨓽',
#   '𨿬',
#   '𩇕',
#   '𩇛',
#   '𩓨',
#   '𩗼',
#   '𩜎',
#   '𪂴',
#   '𫏏',
#   '𫕹',
#   '𫕻',
#   '𮹉',
#   '𬘬',
#   '𬮬',
#   '𬺚',
#   '𭓉',
#   '𭛯',
#   '𭭦',
#   '𭴼',
#   '𭼓',
#   '𮃇',
#   '𮄄',
#   '𬮬',
#   '𮧞',
#   '𮸨',
#   '𮹉',
#   '𰚞',
#   '𰠟',
#   '𰺉',
#   '𲄤'],
#  '204': ['䄇',
#   '䇸',
#   '侱',
#   '呈',
#   '圣',
#   '埕',
#   '徎',
#   '悜',
#   '戜',
#   '挰',
#   '桯',
#   '浧',
#   '珵',
#   '睈',
#   '程',
#   '圣',
#   '脭',
#   '裎',
#   '逞',
#   '郢',
#   '酲',
#   '锃',
#   '锃',
#   '鞓',
#   '𠩥',
#   '𡝚',
#   '𤶲',
#   '𧹓',
#   '𧹓',
#   '𨁎'],
#  '205': ['取', '耴', '踂', '辄', '𦔮'],
#  '206': ['唼', '妾', '接', '椄', '淁', '翣', '踥', '霎', '𧚪', '𪑗'],
#  '207': ['哲', '哳', '悊', '折', '晢', '晣', '淅', '狾', '硩', '蜤', '蜥', '誓', '踅', '逝'],
#  '208': ['㔾', '卩', '卫', '卮', '即', '卸', '卺', '卽', '巵', '疖', '色', '节'],
#  '209': ['㦢', '𰞍', '幯', '栉', '疖', '疖', '节', '节', '𠐉'],
#  '21': ['𰌆',
#   '㟻',
#   '𪮃',
#   '𥇢',
#   '䟅',
#   '𬲕',
#   '䱿',
#   '䳻',
#   '堑',
#   '堑',
#   '崭',
#   '嶃',
#   '崭',
#   '惭',
#   '𰑧',
#   '惭',
#   '𰓼',
#   '斩',
#   '斩',
#   '暂',
#   '暂',
#   '椠',
#   '椠',
#   '渐',
#   '渐',
#   '𰡔',
#   '磛',
#   '𰱑',
#   '𰳂',
#   '覱',
#   '𫏐',
#   '錾',
#   '錾',
#   '𰾌',
#   '𠌲',
#   '𠼃',
#   '𫪚',
#   '𡐛',
#   '𢄤',
#   '𣊙',
#   '𬊗',
#   '𥇢',
#   '𥕌',
#   '𥪭',
#   '𦗚',
#   '𦗝',
#   '𧐮',
#   '𧴃',
#   '𫎸',
#   '𩀧',
#   '𩈻',
#   '𩞏',
#   '𩴕',
#   '𪮃',
#   '𫎸',
#   '𫏐',
#   '𫪚',
#   '𬆂',
#   '𬆂',
#   '𬊗',
#   '𬧋',
#   '𬲕',
#   '𭄇',
#   '𮅼',
#   '𰅨',
#   '𰌆',
#   '𰑧',
#   '𰓼',
#   '𰡔',
#   '𰱑',
#   '𰳂',
#   '𰾌',
#   '𱹿'],
#  '210': ['䕙', '䥫', '嶻', '截', '擮', '铁', '𡽱', '𥵞', '𪖋'],
#  '211': ['倢',
#   '啑',
#   '婕',
#   '寁',
#   '崨',
#   '捷',
#   '疌',
#   '睫',
#   '箑',
#   '脻',
#   '蜨',
#   '踕',
#   '𢈻',
#   '𣮌',
#   '𣶏',
#   '𨓰'],
#  '212': ['𰰺', '设'],
#  '213': ['㞢', '之', '屮', '拜', '艸', '艹', '𡴎', '𢷎'],
#  '214': ['彻', '彻', '撤', '澈', '辙', '辙', '𰕎'],
#  '215': ['䀙',
#   '䟙',
#   '切',
#   '彻',
#   '沏',
#   '砌',
#   '窃',
#   '苆',
#   '袃',
#   '𠯦',
#   '𢗠',
#   '𢗧',
#   '𢪃',
#   '𣐆',
#   '𤆻',
#   '𥾛',
#   '𦕀',
#   '𨥓',
#   '𨥔',
#   '𩚦',
#   '𫊧',
#   '𬍔',
#   '𭎄',
#   '𮅀',
#   '𮤺',
#   '𰎊',
#   '𰹹'],
#  '216': ['㲬',
#   '僬',
#   '噍',
#   '嶕',
#   '嶣',
#   '憔',
#   '樵',
#   '潐',
#   '焦',
#   '燋',
#   '瞧',
#   '礁',
#   '穛',
#   '膲',
#   '蕉',
#   '蟭',
#   '谯',
#   '趭',
#   '醮',
#   '𨱓',
#   '𱂻',
#   '鹪',
#   '鹪',
#   '𢄺',
#   '𦅃',
#   '𨖵',
#   '𨱓',
#   '𨸋',
#   '𨸋'],
#  '217': ['嘲', '庙', '朝', '潮', '𡼼'],
#  '218': ['照', '燳'],
#  '219': ['㲈',
#   '兆',
#   '劭',
#   '卲',
#   '召',
#   '岧',
#   '弨',
#   '怊',
#   '招',
#   '昭',
#   '沼',
#   '灼',
#   '炤',
#   '照',
#   '笤',
#   '绍',
#   '苕',
#   '诏',
#   '貂',
#   '超',
#   '轺',
#   '迢',
#   '邵',
#   '鼗',
#   '韶',
#   '髫',
#   '鼦',
#   '龆',
#   '𠮦',
#   '𦦌'],
#  '22': ['蘸'],
#  '220': ['㲖',
#   '㲵',
#   '䇌',
#   '䏴',
#   '䘯',
#   '䨭',
#   '䴛',
#   '俏',
#   '削',
#   '哨',
#   '娋',
#   '宵',
#   '屑',
#   '峭',
#   '帩',
#   '弰',
#   '悄',
#   '捎',
#   '旓',
#   '梢',
#   '消',
#   '焇',
#   '琑',
#   '痟',
#   '睄',
#   '矟',
#   '硝',
#   '稍',
#   '筲',
#   '绡',
#   '绡',
#   '肖',
#   '艄',
#   '莦',
#   '蛸',
#   '诮',
#   '诮',
#   '赵',
#   '赵',
#   '踃',
#   '輎',
#   '逍',
#   '销',
#   '销',
#   '陗',
#   '霄',
#   '鞘',
#   '𱂉',
#   '颵',
#   '髾',
#   '魈',
#   '𱇯',
#   '𡌔',
#   '𧺉',
#   '𱂉',
#   '𱇯'],
#  '221': ['蒩'],
#  '222': ['藻'],
#  '223': ['早', '草', '𮪤', '𤞋', '𨚰'],
#  '224': ['慅', '搔', '糔', '蚤', '骚', '鳋', '鼜', '𦞣', '𧎮'],
#  '225': ['灶', '灶'],
#  '226': ['唣', '皀', '皁', '皂'],
#  '227': ['慥', '簉', '糙', '艁', '造'],
#  '228': ['艸', '艹', '刍', '草'],
#  '229': ['措', '簎'],
#  '23': ['𡞋',
#   '㟥',
#   '𫶅',
#   '㡎',
#   '𬌷',
#   '㽩',
#   '䅟',
#   '𫎺',
#   '𬱬',
#   '𫢺',
#   '剼',
#   '参',
#   '参',
#   '叅',
#   '𰇼',
#   '𫮅',
#   '㟥',
#   '㡎',
#   '惨',
#   '惨',
#   '掺',
#   '掺',
#   '椮',
#   '椮',
#   '毵',
#   '毶',
#   '毵',
#   '渗',
#   '渗',
#   '犙',
#   '瘆',
#   '瘆',
#   '碜',
#   '碜',
#   '䅟',
#   '𥮾',
#   '糁',
#   '糁',
#   '𰬪',
#   '蔘',
#   '𰴂',
#   '𬢳',
#   '贂',
#   '遪',
#   '𮠳',
#   '𬭝',
#   '骖',
#   '骖',
#   '𩭹',
#   '鯵',
#   '鲹',
#   '鲹',
#   '黪',
#   '黪',
#   '𠔭',
#   '𰄁',
#   '𠫭',
#   '𠬊',
#   '𡞋',
#   '𢕕',
#   '𢿈',
#   '𣪶',
#   '毶',
#   '𰞷',
#   '𤗲',
#   '𤨵',
#   '𥊀',
#   '𥮾',
#   '𦌀',
#   '𦲞',
#   '𧑁',
#   '𧗋',
#   '𨝐',
#   '𨨕',
#   '𫕨',
#   '𩈼',
#   '𩌰',
#   '𩞀',
#   '𩫦',
#   '𩭹',
#   '𩴑',
#   '𪅩',
#   '𫃰',
#   '𫎺',
#   '𫕨',
#   '𫢺',
#   '𫤯',
#   '𫮅',
#   '𫶅',
#   '𬌷',
#   '𬛓',
#   '𬢳',
#   '𬤄',
#   '𬥞',
#   '𬭝',
#   '𬯊',
#   '𬯊',
#   '𬱬',
#   '𬳯',
#   '𮜒',
#   '𮠳',
#   '𰄁',
#   '𰄶',
#   '𰇼',
#   '𰞷',
#   '𰬪',
#   '𰴂',
#   '𰸙',
#   '𰿕',
#   '𱐠',
#   '𱝦',
#   '𱝳',
#   '𱭞',
#   '𱯆',
#   '𱻣'],
#  '230': ['喿', '噪', '懆', '操', '氉', '澡', '燥', '璪', '缲', '臊', '𬤨', '趮', '躁'],
#  '231': ['䜊', '嘈', '曹', '槽', '漕', '糟', '螬', '蹧', '遭', '𫚧', '𡮦'],
#  '232': ['佐', '左', '差'],
#  '233': ['助', '勗', '筯', '耡', '𬬺', '锄'],
#  '234': ['刍',
#   '𫼝',
#   '𬊂',
#   '皱',
#   '皱',
#   '𥬠',
#   '绉',
#   '绉',
#   '刍',
#   '𫇴',
#   '诌',
#   '诌',
#   '趋',
#   '趍',
#   '趋',
#   '邹',
#   '邹',
#   '雏',
#   '雏',
#   '驺',
#   '驺',
#   '𬸅',
#   '𱌭',
#   '𥬠',
#   '𫇴',
#   '𫼝',
#   '𬊂',
#   '𬸅',
#   '𱌭'],
#  '235': ['儊', '楚', '础', '础'],
#  '236': ['㛗',
#   '㟇',
#   '㭫',
#   '䂳',
#   '䟶',
#   '䦷',
#   '䦷',
#   '侳',
#   '剉',
#   '唑',
#   '坐',
#   '夎',
#   '座',
#   '挫',
#   '桽',
#   '痤',
#   '睉',
#   '矬',
#   '脞',
#   '莝',
#   '趖',
#   '锉',
#   '锉',
#   '髽',
#   '𠩜',
#   '𡌚',
#   '𡨠',
#   '𡯨',
#   '𡸄',
#   '𢏬',
#   '𢒐',
#   '𢚂',
#   '𣨎',
#   '𣴳',
#   '𣴶',
#   '𤉛',
#   '𥦊',
#   '𥭭',
#   '𧨀',
#   '𨛏',
#   '𨹫',
#   '𩛠',
#   '𪌴',
#   '𪰦',
#   '𫐩',
#   '𬥗',
#   '𮉴',
#   '𮖉',
#   '𰨃'],
#  '236A': ['座', '蓙', '𡎻', '𣖵', '𨫈', '𪶶', '𭢂'],
#  '237': ['蓌'],
#  '238': ['灾', '灾', '烖'],
#  '239': ['哉', '戴', '栽', '溨', '胾', '裁', '载', '𢦏'],
#  '24': ['㜶',
#   '㸥',
#   '㺥',
#   '䂁',
#   '䧯',
#   '䪌',
#   '儳',
#   '劖',
#   '嚵',
#   '巉',
#   '才',
#   '搀',
#   '搀',
#   '欃',
#   '𫥎',
#   '瀺',
#   '才',
#   '艬',
#   '谗',
#   '谗',
#   '酁',
#   '镵',
#   '镵',
#   '馋',
#   '馋',
#   '𠋂',
#   '𠣄',
#   '𡅛',
#   '𰊅',
#   '𡮿',
#   '𡺎',
#   '𢖞',
#   '𢥋',
#   '𢩢',
#   '𣤱',
#   '𤒰',
#   '𤜇',
#   '𤮭',
#   '𦂯',
#   '𦧻',
#   '𧕃',
#   '𧥓',
#   '𨇩',
#   '𨳂',
#   '𩖌',
#   '𩝎',
#   '𩰃',
#   '𩺒',
#   '𩽝',
#   '𪓄',
#   '𪗂',
#   '𪚃',
#   '𪶳',
#   '𫙭',
#   '𫥎',
#   '𰊅',
#   '𰧫',
#   '𰸤',
#   '𰾠',
#   '𲁰'],
#  '240': ['儎'],
#  '241': ['㱰', '䮨', '宰', '滓', '𰬴', '𣪮', '𤌊'],
#  '242': ['宰', '梓', '辛', '辞', '辤', '辞', '锌'],
#  '243': ['再', '洅'],
#  '244': ['在', '恠', '茬'],
#  '245': ['㥒',
#   '䌽',
#   '䐆',
#   '䣋',
#   '䰂',
#   '倸',
#   '啋',
#   '采',
#   '婇',
#   '寀',
#   '彩',
#   '采',
#   '棌',
#   '睬',
#   '䌽',
#   '菜',
#   '踩',
#   '釆',
#   '采',
#   '𠗡',
#   '𡸯',
#   '𣈄',
#   '𣶶',
#   '𤊕',
#   '𤚀',
#   '𤟖',
#   '𤷕',
#   '𥚖',
#   '𥟩',
#   '𦖗',
#   '𧳥',
#   '𨨫',
#   '𨺉',
#   '𩓰',
#   '𩜓',
#   '𫆇',
#   '𫽱',
#   '𬎱'],
#  '246': ['礤', '蔡', '𤁱', '𨯓', '𩁞', '𩧇', '𪇭'],
#  '247': ['㒲', '䌶', '在', '才', '材', '犲', '豺', '财', '鼒', '𢦏'],
#  '248': ['㤰', '作', '宱', '筰', '莋', '𠈨', '𣨐', '𤶙', '𧧻'],
#  '249': ['凿', '凿'],
#  '25': ['䣟',
#   '僭',
#   '噆',
#   '憯',
#   '替',
#   '朁',
#   '潜',
#   '熸',
#   '簪',
#   '簮',
#   '蚕',
#   '蚕',
#   '谮',
#   '𰾷',
#   '鬵',
#   '𨯩',
#   '𰾷'],
#  '250': ['庄', '庒', '桩', '粧', '脏', '庄', '𢬂'],
#  '251': ['庄', '庒', '臧', '藏', '赃'],
#  '251A': ['舂'],
#  '252': ['壮', '奘', '庄', '庄', '装'],
#  '253': ['塟', '脏', '葬', '脏', '𦵏'],
#  '254': ['䅮',
#   '䢢',
#   '𮠞',
#   '䲝',
#   '䲝',
#   '仓',
#   '伧',
#   '仓',
#   '伧',
#   '𰃷',
#   '刅',
#   '创',
#   '创',
#   '呛',
#   '呛',
#   '嵢',
#   '怆',
#   '怆',
#   '戗',
#   '戗',
#   '抢',
#   '抢',
#   '枪',
#   '枪',
#   '沧',
#   '沧',
#   '炝',
#   '炝',
#   '牄',
#   '𪺷',
#   '玱',
#   '玱',
#   '疮',
#   '疮',
#   '篬',
#   '舱',
#   '舱',
#   '苍',
#   '苍',
#   '螥',
#   '謒',
#   '𬥳',
#   '跄',
#   '跄',
#   '𬬰',
#   '鸧',
#   '鸧',
#   '𠑐',
#   '𠥐',
#   '𣯙',
#   '𤚬',
#   '𤾙',
#   '𥎄',
#   '𥏲',
#   '𥻲',
#   '𦃹',
#   '𬁸',
#   '𧽜',
#   '𨜾',
#   '𨶆',
#   '𩀞',
#   '𩝞',
#   '𩮩',
#   '𪙎',
#   '𪤇',
#   '𪦔',
#   '𪰻',
#   '𪺷',
#   '𫀞',
#   '𬁸',
#   '𬔎',
#   '𬚤',
#   '𬡧',
#   '𬥳',
#   '𬬰',
#   '𮠞',
#   '𰃷',
#   '𰧕',
#   '𱏗',
#   '𱝷',
#   '𱭟',
#   '𲉝',
#   '𲊶'],
#  '255': ['闯', '闯'],
#  '256': ['厂', '厰', '厂', '敞', '氅', '𪅶'],
#  '257': ['床', '𠳹', '𨧖', '𬸐'],
#  '258': ['㶓', '欌', '脏', '藏', '赃', '鑶', '𡿄', '𨤃'],
#  '259': ['𫞛', '储', '槠', '𫉄', '诸', '𢥃'],
#  '26': ['偺', '咎', '喒', '揝', '昝', '糌'],
#  '260': ['㦵',
#   '㧣',
#   '㸡',
#   '㼡',
#   '䇬',
#   '䎷',
#   '䏭',
#   '䣷',
#   '侏',
#   '咮',
#   '姝',
#   '朱',
#   '株',
#   '殊',
#   '洙',
#   '珠',
#   '朱',
#   '祩',
#   '秼',
#   '𰬏',
#   '茱',
#   '蛛',
#   '袾',
#   '诛',
#   '诛',
#   '趎',
#   '跦',
#   '邾',
#   '铢',
#   '铢',
#   '陎',
#   '駯',
#   '鮢',
#   '𱉫',
#   '𬹣',
#   '𠙎',
#   '𠱒',
#   '𡥛',
#   '𡱖',
#   '𢼲',
#   '𣂛',
#   '𣆦',
#   '𣗾',
#   '𣘈',
#   '𤈐',
#   '𤔏',
#   '𤝹',
#   '𤶎',
#   '𥅲',
#   '𦐣',
#   '𦐨',
#   '𦧙',
#   '𧵺',
#   '𨒲',
#   '𨾲',
#   '𩊣',
#   '𩢻',
#   '𩳅',
#   '𪎡',
#   '𪏿',
#   '𪣎',
#   '𪨴',
#   '𪳔',
#   '𫁍',
#   '𫷨',
#   '𫾭',
#   '𬆤',
#   '𬹣',
#   '𮧱',
#   '𰞐',
#   '𰬏',
#   '𱉫',
#   '𲈼'],
#  '261': ['橥', '潴', '猪', '猪'],
#  '262': ['戍', '荗', '𠲌', '𤞉'],
#  '263': ['㹥',
#   '䇠',
#   '䝬',
#   '䪒',
#   '主',
#   '住',
#   '妵',
#   '宔',
#   '往',
#   '拄',
#   '柱',
#   '注',
#   '炷',
#   '疰',
#   '𰬇',
#   '罜',
#   '蛀',
#   '注',
#   '跓',
#   '軴',
#   '迬',
#   '𰽯',
#   '驻',
#   '驻',
#   '麈',
#   '黈',
#   '𠣕',
#   '𠩈',
#   '𠰍',
#   '𠴦',
#   '𥩣',
#   '𦙴',
#   '𩒊',
#   '𩨻',
#   '𪚹'],
#  '264': ['着', '躇', '𣃈'],
#  '265': ['㺛', '𱄼'],
#  '265A': ['処'],
#  '266': ['㕑', '厨', '幮', '厨', '櫉', '橱', '蹰', '𢅥', '𨆼'],
#  '267': ['伫', '咛', '宁', '拧', '柠', '泞', '狞', '竚', '纻', '羜', '苎', '贮', '𫛢'],
#  '268': ['曙', '濖', '糬', '署', '薯', '𨽉'],
#  '269': ['䌸',
#   '䏝',
#   '专',
#   '传',
#   '传',
#   '𰄞',
#   '团',
#   '团',
#   '𫭞',
#   '𰋹',
#   '专',
#   '𰑁',
#   '抟',
#   '抟',
#   '𬇘',
#   '甎',
#   '砖',
#   '砖',
#   '𫁟',
#   '𰩮',
#   '䌸',
#   '䏝',
#   '莼',
#   '莼',
#   '転',
#   '转',
#   '转',
#   '𫚋',
#   '𫁟',
#   '𫚋',
#   '𫭞',
#   '𬇘',
#   '𰄞',
#   '𰋹',
#   '𰑁',
#   '𰩮',
#   '𱈐'],
#  '27': ['㭮', '拶', '𡿪', '𣧄'],
#  '270': ['䔿',
#   '僔',
#   '噂',
#   '墫',
#   '尊',
#   '嶟',
#   '撙',
#   '樽',
#   '𰬺',
#   '罇',
#   '蹲',
#   '遵',
#   '𨱔',
#   '鳟',
#   '鳟',
#   '𫜄',
#   '𥊭',
#   '𥢎',
#   '𨱔',
#   '𩯄'],
#  '271': ['攥', '纂', '𬮃'],
#  '272': ['啭'],
#  '273': ['圳',
#   '巛',
#   '川',
#   '巡',
#   '廵',
#   '𬘓',
#   '训',
#   '钏',
#   '顺',
#   '驯',
#   '𡿪',
#   '𣧄',
#   '𤰕',
#   '𤰝',
#   '𭕆',
#   '𧴲'],
#  '274': ['瑏', '穿', '𨩴'],
#  '275': ['舛', '舜', '荈', '𥬫'],
#  '276': ['撺', '窜', '窜', '蹿'],
#  '277': ['刌',
#   '吋',
#   '夺',
#   '夺',
#   '守',
#   '寸',
#   '对',
#   '寻',
#   '专',
#   '尊',
#   '寻',
#   '对',
#   '忖',
#   '村',
#   '籿',
#   '纣',
#   '肘',
#   '衬',
#   '讨',
#   '酎',
#   '𨙯'],
#  '278': ['串', '患', '窜', '窜'],
#  '279': ['爨'],
#  '28': ['𰃆',
#   '𰉄',
#   '攒',
#   '攒',
#   '𪴙',
#   '瓒',
#   '瓒',
#   '缵',
#   '缵',
#   '臜',
#   '臜',
#   '𬤮',
#   '賛',
#   '赞',
#   '赞',
#   '趱',
#   '趱',
#   '酂',
#   '酂',
#   '鉆',
#   '钻',
#   '钻',
#   '𪴙',
#   '𬤮',
#   '𰃆',
#   '𰉄',
#   '𰿆'],
#  '280': ['㟫',
#   '㣐',
#   '𬭣',
#   '原',
#   '楾',
#   '泉',
#   '湶',
#   '瑔',
#   '线',
#   '腺',
#   '葲',
#   '闎',
#   '騡',
#   '鳈',
#   '𨜩',
#   '𩘘'],
#  '281': ['存', '栫', '洊', '荐'],
#  '282': ['㓌',
#   '㻇',
#   '䀬',
#   '佺',
#   '全',
#   '姾',
#   '峑',
#   '恮',
#   '拴',
#   '栓',
#   '洤',
#   '烇',
#   '牷',
#   '痊',
#   '硂',
#   '筌',
#   '𬘥',
#   '荃',
#   '诠',
#   '诠',
#   '跧',
#   '辁',
#   '辁',
#   '酫',
#   '铨',
#   '铨',
#   '𩧴',
#   '𠓾',
#   '𠛮',
#   '𠤹',
#   '𠱴',
#   '𡋄',
#   '𢂘',
#   '𦓰',
#   '𧊲',
#   '𧻤',
#   '𨛈',
#   '𨹑',
#   '𩧴',
#   '𪰡',
#   '𫆂',
#   '𫗐',
#   '𫗽',
#   '𫤪',
#   '𬍟',
#   '𬘥',
#   '𮁵',
#   '𮱶',
#   '𮳁',
#   '𰙾',
#   '𰷄'],
#  '282A': ['醛'],
#  '283': ['剟',
#   '叕',
#   '啜',
#   '惙',
#   '掇',
#   '敠',
#   '敪',
#   '欼',
#   '歠',
#   '畷',
#   '缀',
#   '蝃',
#   '裰',
#   '辍',
#   '醊',
#   '𮣵',
#   '𬳂'],
#  '284': ['𫦳', '𪮖', '绝', '绝', '脃', '脆', '𫈵'],
#  ...}

# %% [markdown]
# ## Stage 2: Analysis

# %%
# Merge and save to 
df = pd.merge(pinyin_df, radical_df, on="codepoint")

## Stage 2: Analysis

stats = (df.groupby('read')['write'].agg(lambda x: x.value_counts().idxmax()).reset_index())

# %%
print("[*] Analyzing...")

def mapper(ks):
    chars_grps = []
    for key in ks:
        key = key.strip()
        if key in phonetic_dict:
            chars_grps.append(phonetic_dict[key])
    return " | ".join([" ".join(chars) for chars in chars_grps])

stats["map"] = stats.iloc[:, 1].apply(mapper)

stats.to_csv(RESULT_CSV, index=False)

# Above only takes most common by total number of characters, below scales by frequency

freq_df = pd.read_csv(DATA_DIR % "SUBTLEX-CH.csv", sep=",")
freq_df["Word"] = freq_df["Word"].astype(str)
freq_df["WCount"] = pd.to_numeric(freq_df["WCount"], errors="coerce").fillna(0)

# Split multi-character words and divide frequency equally
char_freq = {}
for _, row in freq_df.iterrows():
    word = row["Word"].strip()
    freq = row["WCount"]
    if not word:
        continue
    share = freq / len(word)
    for ch in word:
        char_freq[ch] = char_freq.get(ch, 0) + share

def phonetic_sorter(row):
    read = row["read"]
    keys = row["write"]
    info = []

    for k in keys:
        if k not in phonetic_dict:
            print("[WARN]", k, "not in phonetic_dict!")
            continue

        chars = list(dict.fromkeys(phonetic_dict[k]))  # deduplicate
        same, different = [], []

        for ch in chars:
            freq = char_freq.get(ch, 0.0)
            # Find Mandarin readings for this character
            reads = pinyin_df.loc[pinyin_df["codepoint"] == f"U+{ord(ch):04X}", "read"].tolist()
            if read in reads:
                same.append((ch, freq))
            else:
                different.append((ch, freq))

        # Sort by descending frequency
        same.sort(key=lambda x: x[1], reverse=True)
        different.sort(key=lambda x: x[1], reverse=True)

        info.append({
            k: {
                "same": [c for c, _ in same],
                "different": [c for c, _ in different]
            }
        })

    return info
print("[*]\t Phonetically sorting...")
stats["correspondences"] = stats.apply(phonetic_sorter, axis=1)

# Drop the temporary frequency key
for dlist in stats["correspondences"]:
    for d in dlist:
        for v in d.values():
            v.pop("freq", None)

# Duplication removal
def dedup_string(s):
    """Remove duplicate characters from a string while preserving order."""
    seen = set()
    return ''.join(ch for ch in s if not (ch in seen or seen.add(ch)))

def dedup_phonetic_info(info_list):
    """Remove duplicate characters in 'same' and 'different' lists within the phonetic_info structure."""
    if not isinstance(info_list, list):
        return info_list
    cleaned = []
    for entry in info_list:
        if not isinstance(entry, dict):
            continue
        key = list(entry.keys())[0]
        val = entry[key]
        same = val.get("same", [])
        diff = val.get("different", [])
        # Preserve order
        val["same"] = list(dict.fromkeys(same))
        val["different"] = list(dict.fromkeys(diff))
        cleaned.append({key: val})
    return cleaned

# Apply deduplication
stats["map"] = stats["map"].astype(str).apply(dedup_string)
stats["correspondences"] = stats["correspondences"].apply(dedup_phonetic_info)

# Save final result
stats.to_csv(RESULT_CSV, index=False)

# Summarize below

def extract_summary(info_list):
    if not info_list or not isinstance(info_list, list):
        return pd.Series({
            "1st_write": None,
            "1st_same": [],
            "1st_different": [],
            "1st_same_len": 0,
            "1st_different_len": 0,
            "1st_congruency": 0,
            "most_congruency_write": None,
            "most_congruency_same": [],
            "most_congruency_different": [],
            "most_congruency_same_len": 0,
            "most_congruency_different_len": 0,
            "most_congruency_congruency": 0
        })

    # --- First (most common) phonetic index ---
    first_entry = info_list[0]
    first_key = list(first_entry.keys())[0]
    first_val = first_entry[first_key]
    same = first_val.get("same", [])
    diff = first_val.get("different", [])
    same_len = len(same)
    diff_len = len(diff)
    first_congruency = same_len / (same_len + diff_len) if (same_len + diff_len) > 0 else 0

    # --- Most congruent phonetic index ---
    best_key = None
    best_val = None
    best_congruency = -1
    for entry in info_list:
        k = list(entry.keys())[0]
        v = entry[k]
        s_len = len(v.get("same", []))
        d_len = len(v.get("different", []))
        c = s_len / (s_len + d_len) if (s_len + d_len) > 0 else 0
        if c > best_congruency:
            best_congruency = c
            best_key = k
            best_val = v

    best_same = best_val.get("same", []) if best_val else []
    best_diff = best_val.get("different", []) if best_val else []

    return pd.Series({
        "1st_write": first_key,
        "1st_same": ' '.join(same),
        "1st_different": ' '.join(diff),
        "1st_same_len": same_len,
        "1st_different_len": diff_len,
        "1st_congruency": first_congruency,
        "most_congruency_write": best_key,
        "most_congruency_same": ' '.join(best_same),
        "most_congruency_different": ' '.join(best_diff),
        "most_congruency_same_len": len(best_same),
        "most_congruency_different_len": len(best_diff),
        "most_congruency_congruency": best_congruency
    })

print("[*]\t Extracting summary...")
summary_df = stats["correspondences"].apply(extract_summary)
stats = pd.concat([stats, summary_df], axis=1)

stats.to_csv(RESULT_CSV, index=False)

print("[*] Analysis complete; saved to:", RESULT_CSV)
# Out:
# [*] Analyzing...
# [*]	 Phonetically sorting...
# [*]	 Extracting summary...
# [*] Analysis complete; saved to: result/Stats.csv

# %% [markdown]
# ## Final Output

# %%
stats
# Out:
#      read   write                                                map  \
# 0       a     [3]                                       䋪 啊娿婀屙疴锕阿𠥍𡹣𬮰
# 1      ai   [994]                                         𫣊 嗳嫒爱暧瑷𫉁𰾭叆
# 2      an   [995]                       㝧 䀂䅁䢿侒咹姲安峖按晏案桉氨洝胺荌铵鞌鞍𱂨𫛩𡪙𦛅𧵨𨴣䯃
# 3     ang  [1528]               㼜 㿮䇦䒋𱃵佒央姎岟怏抰映柍殃泱炴盎眏秧紻胦英𬨄𫓭雵鞅𩧫鸯𣃝𧲱𧵌𩲴𪎞𱌀𪚻
# 4      ao   [966]                                傲 厫嗷廒敖滶熬獒璈聱謷赘遨鏊骜鳌鼇𰾧
# ..    ...     ...                                                ...
# 403    zu    [97]  㚗 㡹㸖䏣䖕䢐䢸䣯䪶䯶䱉且伹俎冝刞助咀坥姐宜岨徂怚抯柤查査殂沮爼狙珇疽砠祖租笡粗组罝耝舋苴虘...
# 404  zuan    [28]                                   𰃆 𰉄攒𪴙瓒缵臜𬤮賛赞趱酂鉆钻𰿆
# 405   zui   [291]                                              㠑 嶵檌罪
# 406   zun   [270]                                䔿 僔噂墫尊嶟撙樽𰬺罇蹲遵𨱔鳟𫜄𥊭𥢎𩯄
# 407   zuo    [10]  㡸 㸲𮉣䝫䟭䩆乍作厏咋妰岝岞怍怎拃昨柞泎炸痄砟祚秨窄笮胙舴苲蚱诈迮酢𬬽阼𫗢鲊𱌬𡗸𢂃𣬿𥅁𥹁𦥬𧯤...
#
#                                        correspondences 1st_write  \
# 0    [{'3': {'same': ['啊', '阿', '锕'], 'different': ...         3
# 1    [{'994': {'same': ['爱', '暧', '嗳', '𫣊', '嫒', '瑷...       994
# 2    [{'995': {'same': ['安', '案', '按', '胺', '氨', '鞍...       995
# 3    [{'1528': {'same': ['盎', '㼜', '䇦'], 'different...      1528
# 4    [{'966': {'same': ['傲', '熬', '嗷', '敖', '遨', '獒...       966
# ..                                                 ...       ...
# 403  [{'97': {'same': ['组', '阻', '租', '祖', '诅', '俎'...        97
# 404  [{'28': {'same': ['钻', '缵', '𰿆'], 'different':...        28
# 405  [{'291': {'same': ['罪', '㠑', '嶵', '檌'], 'diffe...       291
# 406  [{'270': {'same': ['尊', '遵', '鳟', '樽', '䔿', '僔...       270
# 407  [{'10': {'same': ['作', '昨', '㸲', '𮉣', '䝫', '岝'...        10
#
#                                 1st_same  \
# 0                                  啊 阿 锕
# 1                      爱 暧 嗳 𫣊 嫒 瑷 𫉁 𰾭 叆
# 2      安 案 按 胺 氨 鞍 铵 桉 䀂 䅁 䢿 侒 峖 洝 荌 鞌 𡪙
# 3                                  盎 㼜 䇦
# 4        傲 熬 嗷 敖 遨 獒 鏊 鳌 骜 厫 廒 滶 璈 聱 謷 鼇
# ..                                   ...
# 403              组 阻 租 祖 诅 俎 䖕 爼 珇 靻 𤱌 𩲲
# 404                                钻 缵 𰿆
# 405                              罪 㠑 嶵 檌
# 406    尊 遵 鳟 樽 䔿 僔 噂 墫 嶟 撙 𰬺 罇 𨱔 𫜄 𥊭 𥢎 𩯄
# 407  作 昨 㸲 𮉣 䝫 岝 岞 怍 祚 秨 胙 酢 𬬽 阼 𫗢 𢂃 𥅁 𦥬
#
#                                          1st_different  1st_same_len  \
# 0                                      婀 䋪 娿 屙 疴 𠥍 𡹣 𬮰             3
# 1                                                                  9
# 2                                  晏 咹 㝧 姲 𱂨 𫛩 𦛅 𧵨 𨴣 䯃            17
# 3    英 映 央 殃 鸯 秧 怏 泱 㿮 䒋 𱃵 佒 姎 岟 抰 柍 炴 眏 紻 胦 𬨄 𫓭 雵 ...             3
# 4                                                  赘 𰾧            16
# ..                                                 ...           ...
# 403  查 且 助 姐 粗 宜 沮 狙 蛆 疽 咀 龃 殂 罝 苴 趄 㚗 㡹 㸖 䏣 䢐 䢸 䣯 ...            12
# 404                            赞 攒 𰃆 𰉄 𪴙 瓒 臜 𬤮 賛 趱 酂 鉆             3
# 405                                                                4
# 406                                                  蹲            17
# 407  怎 炸 诈 咋 窄 乍 蚱 砟 㡸 䟭 䩆 厏 妰 拃 柞 泎 痄 笮 舴 苲 迮 鲊 𱌬 ...            18
#
#      1st_different_len  1st_congruency most_congruency_write  \
# 0                    8        0.272727                     3
# 1                    0        1.000000                   994
# 2                   10        0.629630                   995
# 3                   32        0.085714                  1528
# 4                    2        0.888889                   966
# ..                 ...             ...                   ...
# 403                 79        0.131868                    97
# 404                 12        0.200000                    28
# 405                  0        1.000000                   291
# 406                  1        0.944444                   270
# 407                 33        0.352941                    10
#
#                     most_congruency_same  \
# 0                                  啊 阿 锕
# 1                      爱 暧 嗳 𫣊 嫒 瑷 𫉁 𰾭 叆
# 2      安 案 按 胺 氨 鞍 铵 桉 䀂 䅁 䢿 侒 峖 洝 荌 鞌 𡪙
# 3                                  盎 㼜 䇦
# 4        傲 熬 嗷 敖 遨 獒 鏊 鳌 骜 厫 廒 滶 璈 聱 謷 鼇
# ..                                   ...
# 403              组 阻 租 祖 诅 俎 䖕 爼 珇 靻 𤱌 𩲲
# 404                                钻 缵 𰿆
# 405                              罪 㠑 嶵 檌
# 406    尊 遵 鳟 樽 䔿 僔 噂 墫 嶟 撙 𰬺 罇 𨱔 𫜄 𥊭 𥢎 𩯄
# 407  作 昨 㸲 𮉣 䝫 岝 岞 怍 祚 秨 胙 酢 𬬽 阼 𫗢 𢂃 𥅁 𦥬
#
#                              most_congruency_different  \
# 0                                      婀 䋪 娿 屙 疴 𠥍 𡹣 𬮰
# 1
# 2                                  晏 咹 㝧 姲 𱂨 𫛩 𦛅 𧵨 𨴣 䯃
# 3    英 映 央 殃 鸯 秧 怏 泱 㿮 䒋 𱃵 佒 姎 岟 抰 柍 炴 眏 紻 胦 𬨄 𫓭 雵 ...
# 4                                                  赘 𰾧
# ..                                                 ...
# 403  查 且 助 姐 粗 宜 沮 狙 蛆 疽 咀 龃 殂 罝 苴 趄 㚗 㡹 㸖 䏣 䢐 䢸 䣯 ...
# 404                            赞 攒 𰃆 𰉄 𪴙 瓒 臜 𬤮 賛 趱 酂 鉆
# 405
# 406                                                  蹲
# 407  怎 炸 诈 咋 窄 乍 蚱 砟 㡸 䟭 䩆 厏 妰 拃 柞 泎 痄 笮 舴 苲 迮 鲊 𱌬 ...
#
#      most_congruency_same_len  most_congruency_different_len  \
# 0                           3                              8
# 1                           9                              0
# 2                          17                             10
# 3                           3                             32
# 4                          16                              2
# ..                        ...                            ...
# 403                        12                             79
# 404                         3                             12
# 405                         4                              0
# 406                        17                              1
# 407                        18                             33
#
#      most_congruency_congruency
# 0                      0.272727
# 1                      1.000000
# 2                      0.629630
# 3                      0.085714
# 4                      0.888889
# ..                          ...
# 403                    0.131868
# 404                    0.200000
# 405                    1.000000
# 406                    0.944444
# 407                    0.352941
#
# [408 rows x 16 columns]
